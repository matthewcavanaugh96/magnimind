# %%
# Create dummy and drop first
scout_car_dummies = pd.get_dummies(scout_car['Body Type'], prefix='Body Type', drop_first=True)

# Concat dummies with original dataframe and drop original column
scout_car = pd.concat([scout_car.drop('Body Type', axis=1), scout_car_dummies], axis=1)

# Delete the DataFrame so that the same cell can be reused
del scout_car_dummies

# %% [markdown]
# Already got dummies on Safety, Entertainment etc. Can leave those alone, considering drop_first shouldn't be used for those as any combination of multiple features may exist.
