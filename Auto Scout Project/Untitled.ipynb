# %%
import pandas as pd

# %%
df = pd.read_csv('Step 4 - Final Dataset without dummies.csv')
df = df[['make_model', 'Body Type', 'Price', 'KM']]
df
# Out:
#            make_model Body Type    Price       KM
# 0             Audi A1    Sedans  15770.0  56013.0
# 1             Audi A1    Sedans  14500.0  80000.0
# 2             Audi A1    Sedans  14640.0  83450.0
# 3             Audi A1    Sedans  14500.0  73000.0
# 4             Audi A1    Sedans  16790.0  16200.0
# ...               ...       ...      ...      ...
# 15095  Renault Espace       Van  39950.0     10.0
# 15096  Renault Espace       Van  39885.0   9900.0
# 15097  Renault Espace       Van  39875.0     15.0
# 15098  Renault Espace       Van  39700.0     10.0
# 15099  Renault Espace       Van  40999.0     10.0
#
# [15100 rows x 4 columns]

# %%
df['Price_Vs_Median'] = df['Price'] - df['Price'].median()
df['Price_Vs_Median'].mean()
# Out:
# np.float64(1209.0650662251655)
