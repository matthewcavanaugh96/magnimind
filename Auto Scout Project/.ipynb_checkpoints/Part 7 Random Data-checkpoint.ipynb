# %% [markdown]
# I have had the thought to use our existing dataset to generate a completely new one, with identical features but new data points, and see how our existing models can handle it. Considering that we are already training the entire dataset through KFolds.
#
# Have to refine Joblib model saving.

# %%
import joblib

# %%
linreg = joblib.load('/Users/matthewcavanaugh/Desktop/GitHub/magnimind/Auto Scout Project/Model Storage/linreg.sav')
