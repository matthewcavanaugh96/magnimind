# %% [markdown]
# Part 1: Data Cleaning
#
# Part 2: Missing Values
#
# Part 3: Outlier Analysis
#
# Part 4: Get Dummies
#
# Part 5: Final Dataset EDA
#
# Part 6: Regression Modeling
#
# Part 7: Regression Model Comparison
#
# Part 8: Clustering
#
# <br>
#
# Additional Ideas:
#
# Regression Models with new data (same features just different, or maybe shuffled)
#
# Use Classification models *on* the Regression model results, maybe to predict whether each Regression model overpredicted or underpredicted each car.
#
# Compare models by which columns correlated to larger prediction errors (?)
