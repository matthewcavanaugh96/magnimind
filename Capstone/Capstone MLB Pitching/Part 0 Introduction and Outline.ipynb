# %% [markdown]
# In this project, I will analyze a dataset of 1215 Major League Baseball pitchers and attempt to predict whether each one was named to the National Baseball Hall of Fame. Two criteria have been applied: the pitcher must have thrown a minimum of 1000 career innings (to ensure some amount of longevity), and must have retired no later than 2019 (to account for the time delay in eligibility).
#
# This dataset is highly imbalanced - just 82 of the 1215 pitchers are in the Hall of Fame, and 1133 are not.
#
# I will use (six? seven?) models.
#
# We will use F1 score in Grid Searches. False positives and false negatives are equally important to avoid in this scenario, with no real-world harm to be done by any incorrect prediction.
#
# All models will use K-Fold Cross Validation so that every player can be predicted. I will also include the confidence for each prediction, or the best equivalent possible. This is to allow for more comprehensive aggregation and comparison across models - for example, which players were mostly consistently predicted incorrectly, and which features are correlated to higher errors.

# %% [markdown]
# Note about eligibility:
#
# A player becomes eligible for the Hall of Fame five years after retiring. However, since ballot results are not announced and induction does not take place until the calendar year after voting, the delay is in practice 6 years, which is why 2019 is used as the cutoff.
#
# Players who have retired more recently have had less time eligible, and thus may not be in the Hall of Fame yet even if they make it in the future. I am considering adding a column listing the years elapsed from eligibility to induction. But there are two complications with this:
# 1. A higher number may confuse the model.
# 2. A player may also become eligible six months after dying, which means I would have to add that data to my dataset, and my calculation for eligibility would have to account for this.
