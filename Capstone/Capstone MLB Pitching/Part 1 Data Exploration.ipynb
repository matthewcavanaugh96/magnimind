# %%
import pandas as pd

# %%
all_pitchers_df = pd.read_csv('All Pitchers.txt')
all_pitchers_df
# Out:
#         Rk             Player      IP  From    To    Age    W    L   W-L%  \
# 0        1           Cy Young  7356.0  1890  1911  23-44  511  315  0.619
# 1        2         Pud Galvin  6003.1  1875  1892  18-35  365  310  0.541
# 2        3     Walter Johnson  5914.1  1907  1927  19-39  417  279  0.599
# 3        4        Phil Niekro  5404.0  1964  1987  25-48  318  274  0.537
# 4        5         Nolan Ryan  5386.0  1966  1993  19-46  324  292  0.526
# ...    ...                ...     ...   ...   ...    ...  ...  ...    ...
# 1210  1211  Charlie Robertson  1005.0  1919  1928  23-32   49   80  0.380
# 1211  1212        Sammy Ellis  1004.0  1962  1969  21-28   63   58  0.521
# 1212  1213         Lil Stoner  1003.2  1922  1931  23-32   50   57  0.467
# 1213  1214   Johnny Humphries  1002.0  1938  1946  23-31   52   63  0.452
# 1214  1215         Scott Karl  1002.0  1995  2000  23-28   54   56  0.491
#
#       Dec  ...   FIP   WHIP    H9  HR9  BB9  SO9  SO/BB      Pos  \
# ...
