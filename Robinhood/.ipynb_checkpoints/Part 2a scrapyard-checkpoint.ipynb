# %% [markdown]
# # Unorganized thoughts and bad calculations

# %% [markdown]
# NOTE -
# Assuming that any "missing" days are ones in which the balance went below $10.
#
# I added new rows for the missing days.
#
# Thus, 'active_day' acts as the binary flag for this - 1 indicates an active day, 0 indicates an inactive day in which the balance was below $10.

# %%
import pandas as pd

# %%
equity_df = pd.read_csv('equity_value_data_v2.csv')
equity_df
# Out:
#                     timestamp  close_equity                           user_id  \
# 0        2016-08-18T00:00:00Z     1211.6055  0012db34aa7b083f5714e7831195e54d
# 1        2016-08-19T00:00:00Z     1173.5640  0012db34aa7b083f5714e7831195e54d
# 2        2016-08-22T00:00:00Z     1253.0597  0012db34aa7b083f5714e7831195e54d
# 3        2016-08-23T00:00:00Z     1252.9050  0012db34aa7b083f5714e7831195e54d
# 4        2016-08-24T00:00:00Z     1262.1360  0012db34aa7b083f5714e7831195e54d
# ...                       ...           ...                               ...
# 1119153  2017-08-14T00:00:00Z     2156.2400  ffc1e622f3a0b2666f09a6dcb7f27918
# 1119154  2017-08-15T00:00:00Z     2134.7100  ffc1e622f3a0b2666f09a6dcb7f27918
# 1119155  2017-08-16T00:00:00Z     2152.1200  ffc1e622f3a0b2666f09a6dcb7f27918
# 1119156  2017-08-17T00:00:00Z     2042.2800  ffc1e622f3a0b2666f09a6dcb7f27918
# 1119157  2017-08-18T00:00:00Z     2037.4400  ffc1e622f3a0b2666f09a6dcb7f27918
#
# ...

# %%
# Function to create full date range for one user
def complete_user_dates(user_df):
    full_dates = pd.DataFrame({'date': pd.date_range(user_df['date'].min(), user_df['date'].max())})
    full_dates['user_id'] = user_df['user_id'].iloc[0]
    return full_dates

complete_dates_df = (
    equity_df.groupby('user_id')
    .apply(complete_user_dates)
    .reset_index(drop=True)
)

equity_df['date'] = pd.to_datetime(equity_df['date'])
complete_dates_df['date'] = pd.to_datetime(complete_dates_df['date'])
# Out:
# /var/folders/cf/4zrkk0lx1nbdx9tpklpk4jc00000gn/T/ipykernel_45807/1414377222.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(complete_user_dates)

# %%
# Merge to bring in actual trades
full_equity_df = complete_dates_df.merge(
    equity_df[['user_id', 'date', 'close_equity', 'timestamp']],
    on=['user_id', 'date'],
    how='left'
)

# Sort new DataFrame
full_equity_df = full_equity_df.sort_values(['user_id', 'date'])

# Add binary flag for active/inactive days
full_equity_df['active_day'] = full_equity_df['timestamp'].notna().astype(int)

# HOW TO TREAT CLOSE_EQUITY ON INACTIVE DAYS?
# Fill null close_equity with $9
full_equity_df['close_equity'] = full_equity_df['close_equity'].fillna(9)

# DAILY CHANGE? DOES THIS MAKE SENSE IF I AM LEAVING INACTIVE DAYS NULL?
# Daily change
# full_equity_df['daily_equity_change'] = full_equity_df.groupby('user_id')['close_equity'].diff()

# %%
# Drop timestamp as it no longer has useful information after date was split off.
full_equity_df.drop('timestamp', axis=1, inplace=True)

# %%
full_equity_df = full_equity_df.sort_values(['user_id', 'date'])

# Create a group that increments every time we hit an active day
grp = (
    full_equity_df['active_day']
    .eq(1)
    .groupby(full_equity_df['user_id'])
    .cumsum()
)

# Count days since last active day
full_equity_df['days_since_last_active'] = (
    full_equity_df
    .groupby(['user_id', grp])
    .cumcount()
)

# %%
full_equity_df['streak_at_least_28'] = (full_equity_df['days_since_last_active'] >= 28).astype(int)

# %%
full_equity_df
# Out:
#               date                           user_id  close_equity  \
# 0       2016-08-18  0012db34aa7b083f5714e7831195e54d     1211.6055
# 1       2016-08-19  0012db34aa7b083f5714e7831195e54d     1173.5640
# 2       2016-08-20  0012db34aa7b083f5714e7831195e54d        9.0000
# 3       2016-08-21  0012db34aa7b083f5714e7831195e54d        9.0000
# 4       2016-08-22  0012db34aa7b083f5714e7831195e54d     1253.0597
# ...            ...                               ...           ...
# 1647990 2017-08-14  ffc1e622f3a0b2666f09a6dcb7f27918     2156.2400
# 1647991 2017-08-15  ffc1e622f3a0b2666f09a6dcb7f27918     2134.7100
# 1647992 2017-08-16  ffc1e622f3a0b2666f09a6dcb7f27918     2152.1200
# 1647993 2017-08-17  ffc1e622f3a0b2666f09a6dcb7f27918     2042.2800
# 1647994 2017-08-18  ffc1e622f3a0b2666f09a6dcb7f27918     2037.4400
#
#          active_day  days_since_last_active  streak_at_least_28
# 0                 1                       0                   0
# ...

# %%
full_equity_df['streak_at_least_28'].value_counts()
# Out:
# streak_at_least_28
# 0    1631744
# 1      16251
# Name: count, dtype: int64

# %%
full_equity_df.nlargest(10, 'days_since_last_active')
# Out:
#              date                           user_id  close_equity  active_day  \
# 809736 2017-07-19  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809735 2017-07-18  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809734 2017-07-17  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809733 2017-07-16  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809732 2017-07-15  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809731 2017-07-14  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809730 2017-07-13  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809729 2017-07-12  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809728 2017-07-11  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 809727 2017-07-10  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
#
#         days_since_last_active  streak_at_least_28
# 809736                     334                   1
# ...

# %% [markdown]
# # Features

# %%
features_df = pd.read_csv('features_data.csv')
features_df
# Out:
#            risk_tolerance   investment_experience  \
# 0     high_risk_tolerance  limited_investment_exp
# 1      med_risk_tolerance  limited_investment_exp
# 2      med_risk_tolerance  limited_investment_exp
# 3      med_risk_tolerance  limited_investment_exp
# 4     high_risk_tolerance  limited_investment_exp
# ...                   ...                     ...
# 5579  high_risk_tolerance  limited_investment_exp
# 5580   med_risk_tolerance  limited_investment_exp
# 5581   med_risk_tolerance       no_investment_exp
# 5582   med_risk_tolerance  limited_investment_exp
# 5583  high_risk_tolerance  limited_investment_exp
#
#                   liquidity_needs platform  time_spent  \
# 0         very_important_liq_need  Android   33.129417
# 1         very_important_liq_need  Android   16.573517
# 2         very_important_liq_need      iOS   10.008367
# 3         very_important_liq_need  Android    1.031633
# 4         very_important_liq_need  Android    8.187250
# ...

# %%
# Create flag for users who ever dropped below 10
low_equity_flag = full_equity_df.groupby('user_id')['active_day'].apply(lambda x: (x == 0).any()).astype(int)
# Merge / map into features_df
features_df['ever_below_10'] = features_df['user_id'].map(low_equity_flag)

# Create flag for users with 28 day inactive streak
inactive_streak = full_equity_df.groupby('user_id')['days_since_last_active'].apply(lambda x: (x >= 28).any()).astype(int)
features_df['ever_inactive_28_days'] = features_df['user_id'].map(low_equity_flag)

features_df
# Out:
#            risk_tolerance   investment_experience  \
# 0     high_risk_tolerance  limited_investment_exp
# 1      med_risk_tolerance  limited_investment_exp
# 2      med_risk_tolerance  limited_investment_exp
# 3      med_risk_tolerance  limited_investment_exp
# 4     high_risk_tolerance  limited_investment_exp
# ...                   ...                     ...
# 5579  high_risk_tolerance  limited_investment_exp
# 5580   med_risk_tolerance  limited_investment_exp
# 5581   med_risk_tolerance       no_investment_exp
# 5582   med_risk_tolerance  limited_investment_exp
# 5583  high_risk_tolerance  limited_investment_exp
#
#                   liquidity_needs platform  time_spent  \
# 0         very_important_liq_need  Android   33.129417
# 1         very_important_liq_need  Android   16.573517
# 2         very_important_liq_need      iOS   10.008367
# 3         very_important_liq_need  Android    1.031633
# 4         very_important_liq_need  Android    8.187250
# ...

# %%
features_df['ever_below_10'].value_counts()
# Out:
# ever_below_10
# 1    5560
# 0      24
# Name: count, dtype: int64

# %%
features_df['ever_inactive_28_days'].value_counts()
# Out:
# ever_inactive_28_days
# 1    5560
# 0      24
# Name: count, dtype: int64

# %% [markdown]
# # New dataframe for inactive streaks.

# %%
inactive_streaks_df = pd.DataFrame()
inactive_streaks_df['user_id'] = full_equity_df['user_id']
inactive_streaks_df['days_since_last_active'] = full_equity_df['days_since_last_active']
inactive_streaks_df
# Out:
#                                   user_id  days_since_last_active
# 0        0012db34aa7b083f5714e7831195e54d                       0
# 1        0012db34aa7b083f5714e7831195e54d                       0
# 2        0012db34aa7b083f5714e7831195e54d                       1
# 3        0012db34aa7b083f5714e7831195e54d                       2
# 4        0012db34aa7b083f5714e7831195e54d                       0
# ...                                   ...                     ...
# 1647990  ffc1e622f3a0b2666f09a6dcb7f27918                       0
# 1647991  ffc1e622f3a0b2666f09a6dcb7f27918                       0
# 1647992  ffc1e622f3a0b2666f09a6dcb7f27918                       0
# 1647993  ffc1e622f3a0b2666f09a6dcb7f27918                       0
# 1647994  ffc1e622f3a0b2666f09a6dcb7f27918                       0
#
# [1647995 rows x 2 columns]

# %%
inactive_streaks_df = full_equity_df.copy()
inactive_streaks_df = inactive_streaks_df[inactive_streaks_df['streak_at_least_28'] == 1]
inactive_streaks_df
# Out:
#               date                           user_id  close_equity  \
# 1543    2017-03-27  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1544    2017-03-28  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1545    2017-03-29  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1546    2017-03-30  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1547    2017-03-31  00440034cc4152bfb01b30f5c381c4e3           9.0
# ...            ...                               ...           ...
# 1646447 2017-08-09  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646448 2017-08-10  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646449 2017-08-11  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646450 2017-08-12  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646451 2017-08-13  ff98cbc9633a9255a711d02ebc1e8294           9.0
#
#          active_day  days_since_last_active  streak_at_least_28
# 1543              0                      28                   1
# ...

# %%
# Ensure proper ordering
inactive_streaks_df = inactive_streaks_df.sort_values(['user_id', 'date'])

# Reset streak when it ends
reset = (
    inactive_streaks_df['active_day']
    .eq(1)
    .groupby(inactive_streaks_df['user_id'])
    .cumsum()
)

# Assign streak_id
inactive_streaks_df['streak_id'] = (
    inactive_streaks_df
    .groupby(['user_id', reset])
    .cumcount()
)

# %%
inactive_streaks_df
# Out:
#               date                           user_id  close_equity  \
# 1543    2017-03-27  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1544    2017-03-28  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1545    2017-03-29  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1546    2017-03-30  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1547    2017-03-31  00440034cc4152bfb01b30f5c381c4e3           9.0
# ...            ...                               ...           ...
# 1646447 2017-08-09  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646448 2017-08-10  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646449 2017-08-11  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646450 2017-08-12  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646451 2017-08-13  ff98cbc9633a9255a711d02ebc1e8294           9.0
#
#          active_day  days_since_last_active  streak_at_least_28  streak_id
# 1543              0                      28                   1          0
# ...

# %%
inactive_streaks_df['first_day_of_streak'] = (
    inactive_streaks_df
    .groupby(['user_id', 'streak_id'])['date']
    .transform('min')
)

# %%
inactive_streaks_df
# Out:
#               date                           user_id  close_equity  \
# 1543    2017-03-27  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1544    2017-03-28  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1545    2017-03-29  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1546    2017-03-30  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1547    2017-03-31  00440034cc4152bfb01b30f5c381c4e3           9.0
# ...            ...                               ...           ...
# 1646447 2017-08-09  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646448 2017-08-10  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646449 2017-08-11  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646450 2017-08-12  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646451 2017-08-13  ff98cbc9633a9255a711d02ebc1e8294           9.0
#
#          active_day  days_since_last_active  streak_at_least_28  streak_id  \
# 1543              0                      28                   1          0
# ...

# %%
inactive_streaks_df['user_id'].nunique()
# Out:
# 275

# %%
inactive_streaks_df['streak_id'].nunique()
# Out:
# 307

# %%
inactive_streaks_df['streak_id_2'] = (
    inactive_streaks_df
    .groupby('user_id')['active_day']
    .apply(
        lambda x: ((x == 0) & (x.shift(fill_value=1) == 1)).cumsum()
    )
    .reset_index(level=0, drop=True)
)

# %%
inactive_streaks_df
# Out:
#               date                           user_id  close_equity  \
# 1543    2017-03-27  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1544    2017-03-28  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1545    2017-03-29  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1546    2017-03-30  00440034cc4152bfb01b30f5c381c4e3           9.0
# 1547    2017-03-31  00440034cc4152bfb01b30f5c381c4e3           9.0
# ...            ...                               ...           ...
# 1646447 2017-08-09  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646448 2017-08-10  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646449 2017-08-11  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646450 2017-08-12  ff98cbc9633a9255a711d02ebc1e8294           9.0
# 1646451 2017-08-13  ff98cbc9633a9255a711d02ebc1e8294           9.0
#
#          active_day  days_since_last_active  streak_at_least_28  streak_id  \
# 1543              0                      28                   1          0
# ...

# %%
inactive_streaks_df.groupby(['user_id','streak_id']).size().value_counts()
# Out:
# 1    16251
# Name: count, dtype: int64

# %%
# Ensure 'date' is datetime
inactive_streaks_df['date'] = pd.to_datetime(inactive_streaks_df['date'])

# For each streak, find the index of the row with the earliest date
idx_earliest = inactive_streaks_df.groupby('streak_id')['date'].idxmin()

# Select those rows
streaks_df = inactive_streaks_df.loc[idx_earliest].copy().reset_index(drop=True)

# %%
streaks_df
# Out:
#           date                           user_id  close_equity  active_day  \
# 0   2016-09-15  c0eb9d1466bd8e338cefe499882ad91b           9.0           0
# 1   2016-09-16  c0eb9d1466bd8e338cefe499882ad91b           9.0           0
# 2   2016-09-17  c0eb9d1466bd8e338cefe499882ad91b           9.0           0
# 3   2016-09-18  c0eb9d1466bd8e338cefe499882ad91b           9.0           0
# 4   2016-09-19  c0eb9d1466bd8e338cefe499882ad91b           9.0           0
# ..         ...                               ...           ...         ...
# 302 2017-07-15  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 303 2017-07-16  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 304 2017-07-17  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 305 2017-07-18  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 306 2017-07-19  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
#
#      days_since_last_active  streak_at_least_28  streak_id  \
# ...

# %%
streaks_df = streaks_df.sort_values(['user_id', 'date'])

# %% [markdown]
# # Merge the new columns back into the original dataframe

# %%
# Ensure date is datetime
full_equity_df['date'] = pd.to_datetime(full_equity_df['date'])
streaks_df['first_day_of_streak'] = pd.to_datetime(streaks_df['first_day_of_streak'])

# %%
def equity_before_streak(user_id, streak_start):
    # All days for this user before the streak
    user_days = full_equity_df[
        (full_equity_df['user_id'] == user_id) &
        (full_equity_df['date'] < streak_start)
    ]
    return int((user_days['close_equity'] >= 10).any())

# %%
streaks_df['equity_above_10_before_streak'] = streaks_df.apply(
    lambda row: equity_before_streak(row['user_id'], row['first_day_of_streak']),
    axis=1
)

# %%
streaks_df
# Out:
#           date                           user_id  close_equity  active_day  \
# 130 2017-01-24  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 131 2017-01-25  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 132 2017-01-26  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 133 2017-01-27  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# 134 2017-01-28  7f9dee557e08cd3748fe9f84bb3afc8d           9.0           0
# ..         ...                               ...           ...         ...
# 125 2017-01-18  fbc5223e0b38db36c9b3439326aae416           9.0           0
# 126 2017-01-19  fbc5223e0b38db36c9b3439326aae416           9.0           0
# 127 2017-01-20  fbc5223e0b38db36c9b3439326aae416           9.0           0
# 128 2017-01-21  fbc5223e0b38db36c9b3439326aae416           9.0           0
# 129 2017-01-22  fbc5223e0b38db36c9b3439326aae416           9.0           0
#
#      days_since_last_active  streak_at_least_28  streak_id  \
# ...
