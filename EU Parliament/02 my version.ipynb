# %%
import pandas as pd

url = "https://www.europarl.europa.eu/meps/en/full-list/xml"

df = pd.read_xml(url)
df.head()
# Out:
#                        fullName  country  \
# 0                  Mika AALTOLA  Finland
# 1       Maravillas ABADÍA JOVER    Spain
# 2           Magdalena ADAMOWICZ   Poland
# 3               Georgios AFTIAS   Greece
# 4  Oihane AGIRREGOITIA MARTÍNEZ    Spain
#
#                                       politicalGroup      id  \
# 0  Group of the European People's Party (Christia...  256810
# 1  Group of the European People's Party (Christia...  257043
# 2  Group of the European People's Party (Christia...  197490
# 3  Group of the European People's Party (Christia...  256820
# 4                                 Renew Europe Group  256987
#
#        nationalPoliticalGroup
# 0        Kansallinen Kokoomus
# 1             Partido Popular
# 2                 Independent
# 3              Nea Demokratia
# 4  Partido Nacionalista Vasco

# %%
df
# Out:
#                          fullName   country  \
# 0                    Mika AALTOLA   Finland
# 1         Maravillas ABADÍA JOVER     Spain
# 2             Magdalena ADAMOWICZ    Poland
# 3                 Georgios AFTIAS    Greece
# 4    Oihane AGIRREGOITIA MARTÍNEZ     Spain
# ..                            ...       ...
# 714             Nicola ZINGARETTI     Italy
# 715               Kosma ZŁOTOWSKI    Poland
# 716    Juan Ignacio ZOIDO ÁLVAREZ     Spain
# 717                 Željana ZOVKO   Croatia
# 718                    Milan ZVER  Slovenia
#
#                                         politicalGroup      id  \
# 0    Group of the European People's Party (Christia...  256810
# 1    Group of the European People's Party (Christia...  257043
# 2    Group of the European People's Party (Christia...  197490
# 3    Group of the European People's Party (Christia...  256820
# 4                                   Renew Europe Group  256987
# ...
