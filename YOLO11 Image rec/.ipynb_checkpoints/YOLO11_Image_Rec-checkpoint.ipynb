# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 17.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 15.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.6/783.6 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 19.5 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0
#     Uninstalling torch-2.8.0:
#       Successfully uninstalled torch-2.8.0
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
source = 'http://images.cocodataset.org/val2017/000000039769.jpg'
model.predict(source=source, save=True)
# Out:
# ...
#
# ...
# image 1/1 /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/000000039769.jpg: 480x640 2 cats, 1 couch, 1 remote, 62.0ms
# Speed: 3.7ms preprocess, 62.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to YOLO output image
img_path = '/Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict/000000039769.jpg'

# Load and display
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# # Example 2

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
source = 'dumpster fire.jpeg'
model.predict(source=source, save=True)
# Out:
# image 1/1 /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/dumpster fire.jpeg: 640x448 1 vase, 60.1ms
# Speed: 5.5ms preprocess, 60.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to YOLO output image
img_path = '/Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict2/dumpster fire.jpg'

# Load and display
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# # Example 3

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
source = 'IMG_4177.JPG'
model.predict(source=source, save=True)
# Out:
# image 1/1 /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/IMG_4177.JPG: 640x480 2 chairs, 1 couch, 412.1ms
# Speed: 14.1ms preprocess, 412.1ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to YOLO output image
img_path = '/Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict3/IMG_4177.jpg'

# Load and display
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# # Example 4

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
source = 'IMG_4178.JPG'
model.predict(source=source, save=True)
# Out:
# image 1/1 /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/IMG_4178.JPG: 480x640 2 dogs, 1 potted plant, 1 teddy bear, 74.2ms
# Speed: 9.1ms preprocess, 74.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to YOLO output image
img_path = '/Users/matthewcavanaugh/Desktop/GitHub/magnimind/YOLO11 Image rec/runs/detect/predict4/IMG_4178.jpg'

# Load and display
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()
