# %%
import pandas as pd
df_occupation_data = pd.read_csv('ONET data/Occupation Data.csv')
df_task_statements = pd.read_csv('ONET data/Task Statements.csv')
df_skills = pd.read_csv('ONET data/Skills.csv')
df_abilities = pd.read_csv('ONET data/Abilities.csv')
df_work_activities = pd.read_csv('ONET data/Work Activities.csv')
df_knowledge = pd.read_csv('ONET data/Knowledge.csv')
df_work_context = pd.read_csv('ONET data/Work Context.csv')
df_tools_used = pd.read_csv('ONET data/Tools Used.csv')
df_technology_skills = pd.read_csv('ONET data/Technology Skills.csv')

# %%
df_abilities
# Out:
#       O*NET-SOC Code                              Title Element ID  \
# 0         11-1011.00                   Chief Executives  1.A.1.a.1
# 1         11-1011.00                   Chief Executives  1.A.1.a.1
# 2         11-1011.00                   Chief Executives  1.A.1.a.2
# 3         11-1011.00                   Chief Executives  1.A.1.a.2
# 4         11-1011.00                   Chief Executives  1.A.1.a.3
# ...              ...                                ...        ...
# 92971     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.3
# 92972     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.4
# 92973     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.4
# 92974     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.5
# 92975     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.5
#
#                 Element Name Scale ID  Scale Name  Data Value  N  \
# 0         Oral Comprehension       IM  Importance        4.62  8
# 1         Oral Comprehension       LV       Level        4.88  8
# 2      Written Comprehension       IM  Importance        4.25  8
# 3      Written Comprehension       LV       Level        4.88  8
# 4            Oral Expression       IM  Importance        4.50  8
# ...                      ...      ...         ...         ... ..
# 92971     Sound Localization       LV       Level        2.00  8
# 92972     Speech Recognition       IM  Importance        3.12  8
# 92973     Speech Recognition       LV       Level        2.75  8
# 92974         Speech Clarity       IM  Importance        3.12  8
# 92975         Speech Clarity       LV       Level        2.88  8
#
#        Standard Error  Lower CI Bound  Upper CI Bound Recommend Suppress  \
# 0              0.1830          4.2664          4.9836                  N
# 1              0.1250          4.6300          5.1200                  N
# 2              0.1637          3.9292          4.5708                  N
# 3              0.1250          4.6300          5.1200                  N
# 4              0.1890          4.1296          4.8704                  N
# ...               ...             ...             ...                ...
# 92971          0.0000          2.0000          2.0000                  N
# 92972          0.1250          2.8800          3.3700                  N
# 92973          0.1637          2.4292          3.0708                  N
# 92974          0.1250          2.8800          3.3700                  N
# 92975          0.1250          2.6300          3.1200                  N
#
#       Not Relevant     Date Domain Source
# 0              NaN  08/2023       Analyst
# 1                N  08/2023       Analyst
# 2              NaN  08/2023       Analyst
# 3                N  08/2023       Analyst
# 4              NaN  08/2023       Analyst
# ...            ...      ...           ...
# 92971            N  08/2019       Analyst
# 92972          NaN  08/2019       Analyst
# 92973            N  08/2019       Analyst
# 92974          NaN  08/2019       Analyst
# 92975            N  08/2019       Analyst
#
# [92976 rows x 15 columns]

# %%
df = df_abilities.copy()

# Create combined column label
df["Skill_Scale"] = df["Element Name"] + " " + df["Scale Name"]

# %%
df_wide = df.pivot_table(
    index=["O*NET-SOC Code", "Title"],
    columns="Skill_Scale",
    values="Data Value"
).reset_index()

# %%
df_wide
# Out:
# Skill_Scale O*NET-SOC Code                                             Title  \
# 0               11-1011.00                                  Chief Executives
# 1               11-1011.03                     Chief Sustainability Officers
# 2               11-1021.00                   General and Operations Managers
# 3               11-2011.00               Advertising and Promotions Managers
# 4               11-2021.00                                Marketing Managers
# ..                     ...                                               ...
# 889             53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 890             53-7072.00           Pump Operators, Except Wellhead Pumpers
# 891             53-7073.00                                  Wellhead Pumpers
# 892             53-7081.00         Refuse and Recyclable Material Collectors
# 893             53-7121.00                 Tank Car, Truck, and Ship Loaders
#
# Skill_Scale  Arm-Hand Steadiness Importance  Arm-Hand Steadiness Level  \
# 0                                      1.38                       0.50
# 1                                      1.00                       0.00
# 2                                      1.62                       0.88
# 3                                      1.38                       0.50
# 4                                      1.12                       0.12
# ..                                      ...                        ...
# 889                                    3.88                       3.12
# 890                                    3.12                       3.12
# 891                                    3.00                       2.88
# 892                                    3.25                       2.25
# 893                                    3.38                       3.12
#
# Skill_Scale  Auditory Attention Importance  Auditory Attention Level  \
# 0                                     2.12                      2.00
# 1                                     2.00                      1.75
# 2                                     2.12                      2.00
# 3                                     1.75                      1.25
# 4                                     1.88                      1.62
# ..                                     ...                       ...
# 889                                   3.00                      3.00
# 890                                   3.00                      3.50
# 891                                   2.25                      2.62
# 892                                   2.75                      2.25
# 893                                   3.00                      3.00
#
# Skill_Scale  Category Flexibility Importance  Category Flexibility Level  \
# 0                                       3.50                        4.00
# 1                                       3.12                        3.50
# 2                                       3.38                        3.25
# 3                                       3.38                        3.88
# 4                                       3.25                        3.62
# ..                                       ...                         ...
# 889                                     3.00                        3.00
# 890                                     3.00                        3.12
# 891                                     2.88                        3.00
# 892                                     2.75                        2.38
# 893                                     2.88                        2.88
#
# Skill_Scale  Control Precision Importance  Control Precision Level  ...  \
# 0                                    1.75                     0.75  ...
# 1                                    1.50                     0.50  ...
# 2                                    1.12                     0.12  ...
# 3                                    1.12                     0.12  ...
# 4                                    1.00                     0.00  ...
# ..                                    ...                      ...  ...
# 889                                  3.50                     3.12  ...
# 890                                  3.38                     3.25  ...
# 891                                  3.25                     4.00  ...
# 892                                  2.88                     2.88  ...
# 893                                  3.88                     4.00  ...
#
# Skill_Scale  Visual Color Discrimination Importance  \
# 0                                              2.00
# 1                                              2.12
# 2                                              1.88
# 3                                              2.88
# 4                                              2.88
# ..                                              ...
# 889                                            2.88
# 890                                            3.00
# 891                                            2.00
# 892                                            2.88
# 893                                            2.75
#
# Skill_Scale  Visual Color Discrimination Level  Visualization Importance  \
# 0                                         2.00                      3.00
# 1                                         2.00                      2.75
# 2                                         1.75                      2.75
# 3                                         2.75                      3.25
# 4                                         2.88                      3.00
# ..                                         ...                       ...
# 889                                       2.38                      2.75
# 890                                       3.25                      3.00
# 891                                       1.62                      2.75
# 892                                       2.75                      2.50
# 893                                       2.88                      3.00
#
# Skill_Scale  Visualization Level  Wrist-Finger Speed Importance  \
# 0                           3.38                           1.38
# 1                           2.88                           1.12
# 2                           2.75                           1.75
# 3                           3.12                           1.75
# 4                           3.00                           1.62
# ..                           ...                            ...
# 889                         2.75                           2.00
# 890                         3.25                           2.62
# 891                         3.12                           2.12
# 892                         2.25                           1.62
# 893                         3.00                           2.12
#
# Skill_Scale  Wrist-Finger Speed Level  Written Comprehension Importance  \
# 0                                0.50                              4.25
# 1                                0.12                              4.00
# 2                                0.88                              4.00
# 3                                0.75                              4.00
# 4                                0.75                              4.00
# ..                                ...                               ...
# 889                              2.00                              3.12
# 890                              2.12                              3.12
# 891                              1.62                              2.88
# 892                              1.00                              2.50
# 893                              2.00                              3.00
#
# Skill_Scale  Written Comprehension Level  Written Expression Importance  \
# 0                                   4.88                           4.12
# 1                                   4.25                           4.12
# 2                                   4.00                           4.00
# 3                                   4.00                           3.88
# 4                                   4.12                           3.88
# ..                                   ...                            ...
# 889                                 2.88                           3.00
# 890                                 3.00                           3.25
# 891                                 2.75                           2.62
# 892                                 2.25                           2.50
# 893                                 3.00                           3.00
#
# Skill_Scale  Written Expression Level
# 0                                4.75
# 1                                4.38
# 2                                4.00
# 3                                4.00
# 4                                4.12
# ..                                ...
# 889                              2.88
# 890                              2.88
# 891                              2.38
# 892                              2.00
# 893                              2.75
#
# [894 rows x 106 columns]

# %% [markdown]
# # Z Scores

# %%
df_z = df_wide.copy()

# Identify numeric skill columns
skill_cols = df_wide.select_dtypes(include="number").columns


for col in skill_cols:
    df_z[col] = (
        (df_wide[col] - df_wide[col].mean()) /
        df_wide[col].std()
    )

# %%
meta_cols = ["O*NET-SOC Code", "Title"]

level_cols = [
    col for col in df_z.columns
    if "Level" in col
]

import_cols = [
    col for col in df_z.columns
    if "Importance" in col
]

# %%
df_z
# Out:
# Skill_Scale O*NET-SOC Code                                             Title  \
# 0               11-1011.00                                  Chief Executives
# 1               11-1011.03                     Chief Sustainability Officers
# 2               11-1021.00                   General and Operations Managers
# 3               11-2011.00               Advertising and Promotions Managers
# 4               11-2021.00                                Marketing Managers
# ..                     ...                                               ...
# 889             53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 890             53-7072.00           Pump Operators, Except Wellhead Pumpers
# 891             53-7073.00                                  Wellhead Pumpers
# 892             53-7081.00         Refuse and Recyclable Material Collectors
# 893             53-7121.00                 Tank Car, Truck, and Ship Loaders
#
# Skill_Scale  Arm-Hand Steadiness Importance  Arm-Hand Steadiness Level  \
# 0                                 -1.309117                  -1.417913
# 1                                 -1.731674                  -1.835224
# 2                                 -1.042238                  -1.100757
# 3                                 -1.309117                  -1.417913
# 4                                 -1.598235                  -1.735069
# ..                                      ...                        ...
# 889                                1.470866                   0.768794
# 890                                0.625751                   0.768794
# 891                                0.492312                   0.568485
# 892                                0.770310                   0.042674
# 893                                0.914869                   0.768794
#
# Skill_Scale  Auditory Attention Importance  Auditory Attention Level  \
# 0                                -0.610384                 -0.351005
# 1                                -0.883532                 -0.737513
# 2                                -0.610384                 -0.351005
# 3                                -1.452592                 -1.510529
# 4                                -1.156681                 -0.938497
# ..                                     ...                       ...
# 889                               1.392707                  1.195028
# 890                               1.392707                  1.968044
# 891                              -0.314472                  0.607535
# 892                               0.823647                  0.035503
# 893                               1.392707                  1.195028
#
# Skill_Scale  Category Flexibility Importance  Category Flexibility Level  \
# 0                                   1.039936                    1.489299
# 1                                  -0.061986                    0.507705
# 2                                   0.691961                    0.016909
# 3                                   0.691961                    1.253716
# 4                                   0.314988                    0.743288
# ..                                       ...                         ...
# 889                                -0.409961                   -0.473888
# 890                                -0.409961                   -0.238305
# 891                                -0.757936                   -0.473888
# 892                                -1.134909                   -1.691063
# 893                                -0.757936                   -0.709470
#
# Skill_Scale  Control Precision Importance  Control Precision Level  ...  \
# 0                               -0.738781                -1.076447  ...
# 1                               -1.019770                -1.273121  ...
# 2                               -1.446874                -1.572066  ...
# 3                               -1.446874                -1.572066  ...
# 4                               -1.581748                -1.666470  ...
# ..                                    ...                      ...  ...
# 889                              1.228142                 0.788026  ...
# 890                              1.093267                 0.890297  ...
# 891                              0.947153                 1.480320  ...
# 892                              0.531289                 0.599219  ...
# 893                              1.655245                 1.480320  ...
#
# Skill_Scale  Visual Color Discrimination Importance  \
# 0                                         -1.134934
# 1                                         -0.885583
# 2                                         -1.384285
# 3                                          0.693642
# 4                                          0.693642
# ..                                              ...
# 889                                        0.693642
# 890                                        0.942993
# 891                                       -1.134934
# 892                                        0.693642
# 893                                        0.423511
#
# Skill_Scale  Visual Color Discrimination Level  Visualization Importance  \
# 0                                    -0.633146                  0.444475
# 1                                    -0.633146                 -0.049312
# 2                                    -0.989016                 -0.049312
# 3                                     0.434464                  0.938262
# 4                                     0.619516                  0.444475
# ..                                         ...                       ...
# 889                                  -0.092224                 -0.049312
# 890                                   1.146204                  0.444475
# 891                                  -1.174069                 -0.049312
# 892                                   0.434464                 -0.543099
# 893                                   0.619516                  0.444475
#
# Skill_Scale  Visualization Level  Wrist-Finger Speed Importance  \
# 0                       0.772884                      -1.112450
# 1                       0.047408                      -1.691559
# 2                      -0.141216                      -0.288334
# 3                       0.395636                      -0.288334
# 4                       0.221522                      -0.577888
# ..                           ...                            ...
# 889                    -0.141216                       0.268502
# 890                     0.584260                       1.649453
# 891                     0.395636                       0.535783
# 892                    -0.866693                      -0.577888
# 893                     0.221522                       0.535783
#
# Skill_Scale  Wrist-Finger Speed Level  Written Comprehension Importance  \
# 0                           -1.097846                          1.236142
# 1                           -1.594708                          0.804775
# 2                           -0.600983                          0.804775
# 3                           -0.770962                          0.804775
# 4                           -0.770962                          0.804775
# ..                                ...                               ...
# 889                          0.863455                         -0.713638
# 890                          1.020359                         -0.713638
# 891                          0.366592                         -1.127751
# 892                         -0.444079                         -1.783429
# 893                          0.863455                         -0.920694
#
# Skill_Scale  Written Comprehension Level  Written Expression Importance  \
# 0                               1.482402                       1.246800
# 1                               0.697888                       1.246800
# 2                               0.386574                       1.059743
# 3                               0.386574                       0.872687
# 4                               0.536005                       0.872687
# ..                                   ...                            ...
# 889                            -1.008117                      -0.499062
# 890                            -0.858686                      -0.109360
# 891                            -1.170000                      -1.091408
# 892                            -1.792630                      -1.278464
# 893                            -0.858686                      -0.499062
#
# Skill_Scale  Written Expression Level
# 0                            1.445527
# 1                            1.041509
# 2                            0.626571
# 3                            0.626571
# 4                            0.757604
# ..                                ...
# 889                         -0.596403
# 890                         -0.596403
# 891                         -1.142373
# 892                         -1.557311
# 893                         -0.738355
#
# [894 rows x 106 columns]

# %%
df_z.to_csv('transformed data/5-Abilities Z-Scores.csv', index=False)

# %% [markdown]
# # Z Score aggregates

# %%
df_z_aggs = df_z.copy()



df_z_aggs["z_level_mean"] = df_z_aggs[level_cols].mean(axis=1)
df_z_aggs["z_level_median"] = df_z_aggs[level_cols].median(axis=1)
df_z_aggs["z_level_max"] = df_z_aggs[level_cols].max(axis=1)
df_z_aggs["z_level_min"] = df_z_aggs[level_cols].min(axis=1)
df_z_aggs["z_level_min+max"] = df_z_aggs["z_level_min"] + df_z_aggs["z_level_max"]

df_z_aggs["z_import_mean"] = df_z_aggs[import_cols].mean(axis=1)
df_z_aggs["z_import_median"] = df_z_aggs[import_cols].median(axis=1)
df_z_aggs["z_import_max"] = df_z_aggs[import_cols].max(axis=1)
df_z_aggs["z_import_min"] = df_z_aggs[import_cols].min(axis=1)
df_z_aggs["z_import_min+max"] = df_z_aggs["z_import_min"] + df_z_aggs["z_import_max"]

# Drop level_cols and import_cols as defined earlier
df_z_aggs = df_z_aggs.drop(columns=level_cols)
df_z_aggs = df_z_aggs.drop(columns=import_cols)

# %%
df_z_aggs
# Out:
# Skill_Scale O*NET-SOC Code                                             Title  \
# 0               11-1011.00                                  Chief Executives
# 1               11-1011.03                     Chief Sustainability Officers
# 2               11-1021.00                   General and Operations Managers
# 3               11-2011.00               Advertising and Promotions Managers
# 4               11-2021.00                                Marketing Managers
# ..                     ...                                               ...
# 889             53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 890             53-7072.00           Pump Operators, Except Wellhead Pumpers
# 891             53-7073.00                                  Wellhead Pumpers
# 892             53-7081.00         Refuse and Recyclable Material Collectors
# 893             53-7121.00                 Tank Car, Truck, and Ship Loaders
#
# Skill_Scale  z_level_mean  z_level_median  z_level_max  z_level_min  \
# 0                0.200177       -0.331558     2.357841    -1.778109
# 1               -0.302820       -0.560380     1.687580    -1.917210
# 2               -0.345634       -0.424569     0.861243    -1.961317
# 3               -0.279384       -0.768421     1.545223    -1.572066
# 4               -0.237107       -0.620541     1.719250    -1.735069
# ..                    ...             ...          ...          ...
# 889              0.276459        0.556223     1.743843    -1.315153
# 890              0.469127        0.792002     2.036582    -1.151502
# 891              0.065385        0.325945     1.877516    -1.674839
# 892             -0.335543       -0.121815     1.920157    -3.189658
# 893              0.535274        0.764024     2.276329    -1.132121
#
# Skill_Scale  z_level_min+max  z_import_mean  z_import_median  z_import_max  \
# 0                   0.579732       0.053303        -0.274200      2.095306
# 1                  -0.229629      -0.378665        -0.826140      1.980469
# 2                  -1.100074      -0.298140        -0.428903      1.059743
# 3                  -0.026844      -0.276138        -0.588800      1.742712
# 4                  -0.015819      -0.320981        -0.615790      1.552654
# ..                       ...            ...              ...           ...
# 889                 0.428690       0.378867         0.477653      1.847052
# 890                 0.885080       0.537804         0.680569      2.387878
# 891                 0.202677       0.011227         0.082461      1.808181
# 892                -1.269501      -0.123253         0.224090      2.419066
# 893                 1.144208       0.692370         0.910153      2.588822
#
# Skill_Scale  z_import_min  z_import_min+max
# 0               -1.661826          0.433480
# 1               -1.731674          0.248795
# 2               -1.599025         -0.539282
# 3               -1.452592          0.290120
# 4               -1.655659         -0.103005
# ..                    ...               ...
# 889             -1.437840          0.409211
# 890             -1.238394          1.149484
# 891             -2.003144         -0.194963
# 892             -2.958089         -0.539023
# 893             -1.372352          1.216470
#
# [894 rows x 12 columns]

# %%
df_z_aggs.to_csv('transformed data/5-Abilities Z-Score Aggregates.csv', index=False)

# %%
# Define columns to prefix
cols_to_prefix = df_z_aggs.drop(columns=['O*NET-SOC Code', 'Title']).columns
# Apply prefix to these columns
df_z_aggs_pref = df_z_aggs.rename(columns={c: f'SKILL_{c}' for c in cols_to_prefix})
df_z_aggs_pref
# Out:
# Skill_Scale O*NET-SOC Code                                             Title  \
# 0               11-1011.00                                  Chief Executives
# 1               11-1011.03                     Chief Sustainability Officers
# 2               11-1021.00                   General and Operations Managers
# 3               11-2011.00               Advertising and Promotions Managers
# 4               11-2021.00                                Marketing Managers
# ..                     ...                                               ...
# 889             53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 890             53-7072.00           Pump Operators, Except Wellhead Pumpers
# 891             53-7073.00                                  Wellhead Pumpers
# 892             53-7081.00         Refuse and Recyclable Material Collectors
# 893             53-7121.00                 Tank Car, Truck, and Ship Loaders
#
# Skill_Scale  SKILL_z_level_mean  SKILL_z_level_median  SKILL_z_level_max  \
# 0                      0.200177             -0.331558           2.357841
# 1                     -0.302820             -0.560380           1.687580
# 2                     -0.345634             -0.424569           0.861243
# 3                     -0.279384             -0.768421           1.545223
# 4                     -0.237107             -0.620541           1.719250
# ..                          ...                   ...                ...
# 889                    0.276459              0.556223           1.743843
# 890                    0.469127              0.792002           2.036582
# 891                    0.065385              0.325945           1.877516
# 892                   -0.335543             -0.121815           1.920157
# 893                    0.535274              0.764024           2.276329
#
# Skill_Scale  SKILL_z_level_min  SKILL_z_level_min+max  SKILL_z_import_mean  \
# 0                    -1.778109               0.579732             0.053303
# 1                    -1.917210              -0.229629            -0.378665
# 2                    -1.961317              -1.100074            -0.298140
# 3                    -1.572066              -0.026844            -0.276138
# 4                    -1.735069              -0.015819            -0.320981
# ..                         ...                    ...                  ...
# 889                  -1.315153               0.428690             0.378867
# 890                  -1.151502               0.885080             0.537804
# 891                  -1.674839               0.202677             0.011227
# 892                  -3.189658              -1.269501            -0.123253
# 893                  -1.132121               1.144208             0.692370
#
# Skill_Scale  SKILL_z_import_median  SKILL_z_import_max  SKILL_z_import_min  \
# 0                        -0.274200            2.095306           -1.661826
# 1                        -0.826140            1.980469           -1.731674
# 2                        -0.428903            1.059743           -1.599025
# 3                        -0.588800            1.742712           -1.452592
# 4                        -0.615790            1.552654           -1.655659
# ..                             ...                 ...                 ...
# 889                       0.477653            1.847052           -1.437840
# 890                       0.680569            2.387878           -1.238394
# 891                       0.082461            1.808181           -2.003144
# 892                       0.224090            2.419066           -2.958089
# 893                       0.910153            2.588822           -1.372352
#
# Skill_Scale  SKILL_z_import_min+max
# 0                          0.433480
# 1                          0.248795
# 2                         -0.539282
# 3                          0.290120
# 4                         -0.103005
# ..                              ...
# 889                        0.409211
# 890                        1.149484
# 891                       -0.194963
# 892                       -0.539023
# 893                        1.216470
#
# [894 rows x 12 columns]
