# %%
df_occupation_data
# Out:
#      O*NET-SOC Code                                              Title  \
# 0        11-1011.00                                   Chief Executives
# 1        11-1011.03                      Chief Sustainability Officers
# 2        11-1021.00                    General and Operations Managers
# 3        11-1031.00                                        Legislators
# 4        11-2011.00                Advertising and Promotions Managers
# ...             ...                                                ...
# 1011     55-3014.00                 Artillery and Missile Crew Members
# 1012     55-3015.00             Command and Control Center Specialists
# 1013     55-3016.00                                           Infantry
# 1014     55-3018.00                                     Special Forces
# 1015     55-3019.00  Military Enlisted Tactical Operations and Air/...
#
#                                             Description
# 0     Determine and formulate policies and provide o...
# 1     Communicate and coordinate with management, sh...
# 2     Plan, direct, or coordinate the operations of ...
# 3     Develop, introduce, or enact laws and statutes...
# 4     Plan, direct, or coordinate advertising polici...
# ...                                                 ...
# 1011  Target, fire, and maintain weapons used to des...
# 1012  Operate and monitor communications, detection,...
# 1013  Operate weapons and equipment in ground combat...
# 1014  Implement unconventional operations by air, la...
# 1015  All military enlisted tactical operations and ...
#
# [1016 rows x 3 columns]

# %%
df_occupation_data.columns
# Out:
# Index(['O*NET-SOC Code', 'Title', 'Description'], dtype='object')

# %% [markdown]
# # Attributes - Rough idea, could alter

# %% [markdown]
# ALSO TO ADD
#
# TECH TOOL AND TASK UNIQUENESS - 10% ? At which metric's expense?

# %% [markdown]
# Each will be normalized for directionality.

# %% [markdown]
# 1. Routine structure - How repetitive is the job, how predictable are the tasks?
#
# 2. Cognitive complexity - How advanced is the reasoning required by this job? Do unique problems arise which cannot be solved with simple rules?
#
# 3. Physical requirements - How much physical activity is required? Lifting, manual adjustments, etc.
#
# 4. Social interactions - How frequently does the job require interactions with people? How important are these interactions to job success? How complex are these interactions i.e. do they require more depth than, for instance, a phonebot that forces selection from a narrow list to hear pre-recorded answers?
#
# 5. Creativity - How much is originality incentivized over following instructions?
#
# 6. Decision accountability - How crucial are the decisions being made, and to what extent is it preferred that humans have final say-so above automated processes?
#
# 7. Data structure - How readily available are structured data and objective performance metrics?

# %% [markdown]
# Dimension Weights
#
# Routine - 20% - Positive impact on score
#
# Cognitive complexity - 15% - Negative impact on score
#
# Physical requirements - 15% - Negative impact on score
#
# Social interactions - 15% - Negative impact on score
#
# Creativity - 15% - Negative impact on score
#
# Decision accountability 10% - Negative impact on score
#
# Data structure 10% - Positive impact on score

# %% [markdown]
# I will ask AI tools to score each of these dimensions for each job on a scale of 1 to 5. Will likely ask multiple agents and take an average.
#
# (The hook could be something like - does AI think it's coming for your job?)
#
# Some may have to be inverted depending whether a higher or lower score is correlated with AI risk.
#
# The AI scores will be combined with existing metrics already scaled 1 to 5, and others that have been rescaled.
#
# Weights may be adjusted as more things are added.
