# %%
import pandas as pd

df_occupation_data = pd.read_csv('ONET data/Occupation Data.csv')
df_task_statements = pd.read_csv('ONET data/Task Statements.csv')
df_skills = pd.read_csv('ONET data/Skills.csv')
df_abilities = pd.read_csv('ONET data/Abilities.csv')
df_work_activities = pd.read_csv('ONET data/Work Activities.csv')
df_knowledge = pd.read_csv('ONET data/Knowledge.csv')
df_work_context = pd.read_csv('ONET data/Work Context.csv')
df_tools_used = pd.read_csv('ONET data/Tools Used.csv')
df_technology_skills = pd.read_csv('ONET data/Technology Skills.csv')

dfs = {
    "occupation_data": df_occupation_data,
    "task_statements": df_task_statements,
    "skills": df_skills,
    "abilities": df_abilities,
    "work_activities": df_work_activities,
    "knowledge": df_knowledge,
    "work_context": df_work_context,
    "tools_used": df_tools_used,
    "technology_skills": df_technology_skills
}

# %% [markdown]
# # Technology Aggregates

# %%
df_technology_skills
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 32768     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32769     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32770     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32771     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32772     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                              Example  Commodity Code  \
# 0                                      Adobe Acrobat        43232202
# 1                                    AdSense Tracker        43232306
# 2                                     Atlassian JIRA        43232201
# 3                        Blackbaud The Raiser's Edge        43232303
# 4      ComputerEase construction accounting software        43231601
# ...                                              ...             ...
# 32768                                          Linux        43233004
# 32769                                Microsoft Excel        43232110
# 32770                      Microsoft Office software        43231513
# 32771                                   SAP software        43231602
# 32772                Warehouse management system WMS        43231506
#
#                                          Commodity Title Hot Technology  \
# 0                           Document management software              Y
# 1            Data base user interface and query software              N
# 2                              Content workflow software              Y
# 3          Customer relationship management CRM software              N
# 4                                    Accounting software              N
# ...                                                  ...            ...
# 32768                          Operating system software              Y
# 32769                               Spreadsheet software              Y
# 32770                              Office suite software              Y
# 32771          Enterprise resource planning ERP software              Y
# 32772  Materials requirements planning logistics and ...              N
#
#       In Demand
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
# ...         ...
# 32768         N
# 32769         N
# 32770         N
# 32771         N
# 32772         N
#
# [32773 rows x 7 columns]

# %%
df_technology_skills.columns
# Out:
# Index(['O*NET-SOC Code', 'Title', 'Example', 'Commodity Code',
#        'Commodity Title', 'Hot Technology', 'In Demand'],
#       dtype='object')

# %%
df_technology_skills['O*NET-SOC Code'].nunique()
# Out:
# 923

# %%
df_technology_skills['Title'].nunique()
# Out:
# 923

# %%
df_technology_skills['Example'].nunique()
# Out:
# 8785

# %%
df_technology_skills['Commodity Code'].nunique()
# Out:
# 137

# %%
df_technology_skills['Commodity Title'].nunique()
# Out:
# 137

# %% [markdown]
# # Tech Skills - Software skills aggregated by job

# %%
# Create dataframe titles_skills_and_commods, with aggregates about software for each Title

# Reset DF definition
df_technology_skills = pd.read_csv('ONET data/Technology Skills.csv')

# Reformat Y/N columns to 1/0, change to binary
df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].replace('Y', 1)
df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].replace('N', 0)
df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].astype(int)

df_technology_skills['In Demand'] = df_technology_skills['In Demand'].replace('Y', 1)
df_technology_skills['In Demand'] = df_technology_skills['In Demand'].replace('N', 0)
df_technology_skills['In Demand'] = df_technology_skills['In Demand'].astype(int)


# Find count of unique skills by title
total_skills_by_title = (
    df_technology_skills
    .groupby(['O*NET-SOC Code', 'Title'])['Example']
    .nunique()
    .reset_index(name='TOTAL_EXAMPLES')
    .sort_values('TOTAL_EXAMPLES', ascending=False)
)

# Find count of unique commodities by title
total_commods_by_title = (
    df_technology_skills
    .groupby(['O*NET-SOC Code', 'Title'])['Commodity Code']
    .nunique()
    .reset_index(name='TOTAL_COMMODITIES')
    .sort_values('TOTAL_COMMODITIES', ascending=False)
)

# Merge
titles_skills_and_commods = pd.merge(total_skills_by_title, total_commods_by_title, on=['O*NET-SOC Code', 'Title'], how='inner')

# Create column list of all unique examples by title
examples_by_title = (
    df_technology_skills
    .groupby('Title')['Example']
    .apply(lambda x: '; '.join(
        f'"{e}"' for e in sorted(x.unique())
    ))
    .reset_index(name='EXAMPLE_LIST')
)

# Merge
titles_skills_and_commods = titles_skills_and_commods.merge(
    examples_by_title,
    on='Title',
    how='left'
)

# Create column list of all unique commodities by title
commods_by_title = (
    df_technology_skills
    .groupby('Title')['Commodity Title']
    .apply(lambda x: '; '.join(
        f'"{e}"' for e in sorted(x.unique())
    ))
    .reset_index(name='COMMODITY_LIST')
)

# Merge
titles_skills_and_commods = titles_skills_and_commods.merge(
    commods_by_title,
    on='Title',
    how='left'
)


# For each job, find the percentage of software used that is considered Hot Technology
title_example_hot = (
    df_technology_skills
    .groupby(['Title', 'Example'])['Hot Technology']
    .max()   # if any row is 1 → result is 1
    .reset_index()
)

hot_percentage = (
    title_example_hot
    .groupby('Title')['Hot Technology']
    .agg(['mean', 'sum', 'count'])
    .reset_index()
)

hot_percentage = hot_percentage.rename(columns={
    'mean': 'PCT_HOT_TECHNOLOGY',
    'sum': 'NUM_HOT_EXAMPLES',
    'count': 'TOTAL_EXAMPLES'
})

hot_percentage['PCT_HOT_TECHNOLOGY'] *= 100

titles_skills_and_commods = titles_skills_and_commods.merge(
    hot_percentage,
    on='Title',
    how='left'
)



# For each job, find the percentage of software used that is considered In Demand
title_example_demand = (
    df_technology_skills
    .groupby(['Title', 'Example'])['In Demand']
    .max()   # if any row is 1 → result is 1
    .reset_index()
)

demand_percentage = (
    title_example_demand
    .groupby('Title')['In Demand']
    .agg(['mean', 'sum', 'count'])
    .reset_index()
)

demand_percentage = demand_percentage.rename(columns={
    'mean': 'PCT_IN_DEMAND',
    'sum': 'NUM_IN_DEMAND_EXAMPLES',
    'count': 'TOTAL_EXAMPLES'
})

demand_percentage['PCT_IN_DEMAND'] *= 100

titles_skills_and_commods = titles_skills_and_commods.merge(
    demand_percentage,
    on='Title',
    how='left'
)


# Merging cause column name wonkiness - drop redundant columns, rename original
titles_skills_and_commods = titles_skills_and_commods.drop(
    columns=['TOTAL_EXAMPLES_y', 'TOTAL_EXAMPLES']
)

titles_skills_and_commods = titles_skills_and_commods.rename(
    columns={'TOTAL_EXAMPLES_x': 'TOTAL_EXAMPLES'}
)


titles_skills_and_commods
# Out:
# /var/folders/cf/4zrkk0lx1nbdx9tpklpk4jc00000gn/T/ipykernel_13361/2226831198.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].replace('N', 0)
# /var/folders/cf/4zrkk0lx1nbdx9tpklpk4jc00000gn/T/ipykernel_13361/2226831198.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_technology_skills['In Demand'] = df_technology_skills['In Demand'].replace('N', 0)
#     O*NET-SOC Code                                              Title  \
# 0       15-1252.00                                Software Developers
# 1       15-1253.00    Software Quality Assurance Analysts and Testers
# 2       15-1299.09            Information Technology Project Managers
# 3       15-1243.00                                Database Architects
# 4       15-1211.00                          Computer Systems Analysts
# ..             ...                                                ...
# 918     35-9021.00                                        Dishwashers
# 919     53-7041.00                          Hoist and Winch Operators
# 920     53-4041.00                     Subway and Streetcar Operators
# 921     51-4023.00  Rolling Machine Setters, Operators, and Tender...
# 922     51-3093.00         Food Cooking Machine Operators and Tenders
#
#      TOTAL_EXAMPLES  TOTAL_COMMODITIES  \
# 0               429                 67
# 1               428                 68
# 2               334                 62
# 3               324                 59
# 4               313                 68
# ..              ...                ...
# 918               2                  2
# 919               2                  2
# 920               2                  2
# 921               2                  2
# 922               1                  1
#
#                                           EXAMPLE_LIST  \
# 0    "3M Post-it App"; "A programming language APL"...
# 1    "3M Post-it App"; "A programming language APL"...
# 2    "24SevenOffice Project"; "3M Post-it App"; "AE...
# 3    "3M Post-it App"; "ADO.NET"; "AJAX"; "ASG Tech...
# 4    "3M Post-it App"; "ADP Workforce Now"; "AJAX";...
# ..                                                 ...
# 918                    "Facebook"; "Microsoft Windows"
# 919                "Microsoft Excel"; "Microsoft Word"
# 920  "Microsoft Office software"; "Word processing ...
# 921           "Email software"; "Web browser software"
# 922                                "Database software"
#
#                                         COMMODITY_LIST  PCT_HOT_TECHNOLOGY  \
# 0    "Access software"; "Administration software"; ...           34.498834
# 1    "Access software"; "Accounting software"; "Adm...           28.971963
# 2    "Access software"; "Accounting software"; "Ana...           36.227545
# 3    "Access software"; "Administration software"; ...           34.567901
# 4    "Access software"; "Accounting software"; "Adm...           38.019169
# ..                                                 ...                 ...
# 918  "Operating system software"; "Web page creatio...          100.000000
# 919  "Spreadsheet software"; "Word processing softw...          100.000000
# 920  "Office suite software"; "Word processing soft...           50.000000
# 921  "Electronic mail software"; "Internet browser ...            0.000000
# 922      "Data base user interface and query software"            0.000000
#
#      NUM_HOT_EXAMPLES  PCT_IN_DEMAND  NUM_IN_DEMAND_EXAMPLES
# 0                 148       7.692308                      33
# 1                 124       5.140187                      22
# 2                 121       2.694611                       9
# 3                 112       4.012346                      13
# 4                 119       3.514377                      11
# ..                ...            ...                     ...
# 918                 2       0.000000                       0
# 919                 2       0.000000                       0
# 920                 1       0.000000                       0
# 921                 0       0.000000                       0
# 922                 0       0.000000                       0
#
# [923 rows x 10 columns]

# %%
titles_skills_and_commods.rename(columns={'TOTAL_EXAMPLES': 'TOTAL_TECH_SKILLS'}, inplace=True)
titles_skills_and_commods.rename(columns={'TOTAL_COMMODITIES': 'TOTAL_TECH_TYPES'}, inplace=True)
titles_skills_and_commods.rename(columns={'PCT_HOT_TECHNOLOGY': 'PCT_HOT_TECH'}, inplace=True)
titles_skills_and_commods.rename(columns={'NUM_HOT_EXAMPLES': 'NUM_HOT_TECH'}, inplace=True)
titles_skills_and_commods.rename(columns={'PCT_IN_DEMAND': 'PCT_IN_DEMAND_TECH'}, inplace=True)
titles_skills_and_commods.rename(columns={'NUM_IN_DEMAND_EXAMPLES': 'NUM_IN_DEMAND_TECH'}, inplace=True)
titles_skills_and_commods.rename(columns={'EXAMPLE_LIST': 'TECH_SKILLS_LIST'}, inplace=True)
titles_skills_and_commods.rename(columns={'COMMODITY_LIST': 'TECH_TYPES_LIST'}, inplace=True)
titles_skills_and_commods.rename(columns={'Title': 'Job Title'}, inplace=True)

# %%
titles_skills_and_commods
# Out:
#     O*NET-SOC Code                                          Job Title  \
# 0       15-1252.00                                Software Developers
# 1       15-1253.00    Software Quality Assurance Analysts and Testers
# 2       15-1299.09            Information Technology Project Managers
# 3       15-1243.00                                Database Architects
# 4       15-1211.00                          Computer Systems Analysts
# ..             ...                                                ...
# 918     35-9021.00                                        Dishwashers
# 919     53-7041.00                          Hoist and Winch Operators
# 920     53-4041.00                     Subway and Streetcar Operators
# 921     51-4023.00  Rolling Machine Setters, Operators, and Tender...
# 922     51-3093.00         Food Cooking Machine Operators and Tenders
#
#      TOTAL_TECH_SKILLS  TOTAL_TECH_TYPES  \
# 0                  429                67
# 1                  428                68
# 2                  334                62
# 3                  324                59
# 4                  313                68
# ..                 ...               ...
# 918                  2                 2
# 919                  2                 2
# 920                  2                 2
# 921                  2                 2
# 922                  1                 1
#
#                                       TECH_SKILLS_LIST  \
# 0    "3M Post-it App"; "A programming language APL"...
# 1    "3M Post-it App"; "A programming language APL"...
# 2    "24SevenOffice Project"; "3M Post-it App"; "AE...
# 3    "3M Post-it App"; "ADO.NET"; "AJAX"; "ASG Tech...
# 4    "3M Post-it App"; "ADP Workforce Now"; "AJAX";...
# ..                                                 ...
# 918                    "Facebook"; "Microsoft Windows"
# 919                "Microsoft Excel"; "Microsoft Word"
# 920  "Microsoft Office software"; "Word processing ...
# 921           "Email software"; "Web browser software"
# 922                                "Database software"
#
#                                        TECH_TYPES_LIST  PCT_HOT_TECH  \
# 0    "Access software"; "Administration software"; ...     34.498834
# 1    "Access software"; "Accounting software"; "Adm...     28.971963
# 2    "Access software"; "Accounting software"; "Ana...     36.227545
# 3    "Access software"; "Administration software"; ...     34.567901
# 4    "Access software"; "Accounting software"; "Adm...     38.019169
# ..                                                 ...           ...
# 918  "Operating system software"; "Web page creatio...    100.000000
# 919  "Spreadsheet software"; "Word processing softw...    100.000000
# 920  "Office suite software"; "Word processing soft...     50.000000
# 921  "Electronic mail software"; "Internet browser ...      0.000000
# 922      "Data base user interface and query software"      0.000000
#
#      NUM_HOT_TECH  PCT_IN_DEMAND_TECH  NUM_IN_DEMAND_TECH
# 0             148            7.692308                  33
# 1             124            5.140187                  22
# 2             121            2.694611                   9
# 3             112            4.012346                  13
# 4             119            3.514377                  11
# ..            ...                 ...                 ...
# 918             2            0.000000                   0
# 919             2            0.000000                   0
# 920             1            0.000000                   0
# 921             0            0.000000                   0
# 922             0            0.000000                   0
#
# [923 rows x 10 columns]

# %%
titles_skills_and_commods.to_csv('transformed data/1-Jobs Agg Tech Skills.csv', index=False)

# %% [markdown]
# # Aggregates by Software.
# Confirmed that each 'EXAMPLE' (software name) is only associated with one 'COMMODITY TITLE' (software type).

# %%
# Reset DF definition
df_technology_skills = pd.read_csv('ONET data/Technology Skills.csv')

# Reformat Y/N columns to 1/0, change to binary
df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].replace('Y', 1)
df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].replace('N', 0)
df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].astype(int)

df_technology_skills['In Demand'] = df_technology_skills['In Demand'].replace('Y', 1)
df_technology_skills['In Demand'] = df_technology_skills['In Demand'].replace('N', 0)
df_technology_skills['In Demand'] = df_technology_skills['In Demand'].astype(int)
# Out:
# /var/folders/cf/4zrkk0lx1nbdx9tpklpk4jc00000gn/T/ipykernel_13361/3719657155.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_technology_skills['Hot Technology'] = df_technology_skills['Hot Technology'].replace('N', 0)
# /var/folders/cf/4zrkk0lx1nbdx9tpklpk4jc00000gn/T/ipykernel_13361/3719657155.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_technology_skills['In Demand'] = df_technology_skills['In Demand'].replace('N', 0)

# %%
jobs_per_software = (
    df_technology_skills
    .groupby(['Example'])['Title']
    .nunique()
    .reset_index(name='TOTAL_JOBS_PER_SOFTWARE')
    .sort_values('TOTAL_JOBS_PER_SOFTWARE', ascending=False)
)

jobs_per_soft_type = (
    df_technology_skills
    .groupby(['Commodity Title'])['Title']
    .nunique()
    .reset_index(name='TOTAL_JOBS_PER_SOFTWARE_TYPE')
    .sort_values('TOTAL_JOBS_PER_SOFTWARE_TYPE', ascending=False)
)

murjd_df = df_technology_skills.merge(
    jobs_per_software,
    on='Example',
    how='left'
)

murjd_df = murjd_df.merge(
    jobs_per_soft_type,
    on='Commodity Title',
    how='left'
)

software_examples_df = murjd_df[['Example', 'Commodity Title', 'Commodity Code', 'Hot Technology', 'In Demand', 'TOTAL_JOBS_PER_SOFTWARE', 'TOTAL_JOBS_PER_SOFTWARE_TYPE']]
software_examples_df = software_examples_df.drop_duplicates(subset=['Example'], keep='first')

software_examples_df
# Out:
#                                              Example  \
# 0                                      Adobe Acrobat
# 1                                    AdSense Tracker
# 2                                     Atlassian JIRA
# 3                        Blackbaud The Raiser's Edge
# 4      ComputerEase construction accounting software
# ...                                              ...
# 32756                                  AMCS Platform
# 32758                               Dossier software
# 32761                       Mileage logging software
# 32763                             Routeware software
# 32766                                 CompuWeigh GMS
#
#                                      Commodity Title  Commodity Code  \
# 0                       Document management software        43232202
# 1        Data base user interface and query software        43232306
# 2                          Content workflow software        43232201
# 3      Customer relationship management CRM software        43232303
# 4                                Accounting software        43231601
# ...                                              ...             ...
# 32756              Analytical or scientific software        43232605
# 32758    Data base user interface and query software        43232306
# 32761    Data base user interface and query software        43232306
# 32763                          Map creation software        43233506
# 32766    Data base user interface and query software        43232306
#
#        Hot Technology  In Demand  TOTAL_JOBS_PER_SOFTWARE  \
# 0                   1          0                      165
# 1                   0          0                        2
# 2                   1          0                       53
# 3                   0          0                       44
# 4                   0          0                        3
# ...               ...        ...                      ...
# 32756               0          0                        1
# 32758               0          0                        1
# 32761               0          0                        1
# 32763               0          0                        1
# 32766               0          0                        1
#
#        TOTAL_JOBS_PER_SOFTWARE_TYPE
# 0                               293
# 1                               632
# 2                                46
# 3                               155
# 4                               178
# ...                             ...
# 32756                           372
# 32758                           632
# 32761                           632
# 32763                            87
# 32766                           632
#
# [8785 rows x 7 columns]

# %%
# Create column list of all unique commodities by (Job)title
jobs_by_software = (
    df_technology_skills
    .groupby('Example')['Title']
    .apply(lambda x: '; '.join(
        f'"{e}"' for e in sorted(x.unique())
    ))
    .reset_index(name='JOB_TITLE_LIST')
)

jobs_by_software
# Out:
#                                         Example  \
# 0                !Trak-it Solutions !Trak-it HR
# 1                100 Plus Hatch Pattern Library
# 2     1003 Uniform Residential Loan Application
# 3                             1099 ProsSoftware
# 4                           1CadCam Unigraphics
# ...                                         ...
# 8780                                     xQuery
# 8781                                         xv
# 8782                                  yieldWerx
# 8783                                     z-Tree
# 8784                                   zkipster
#
#                                          JOB_TITLE_LIST
# 0                  "Compensation and Benefits Managers"
# 1                    "Architectural and Civil Drafters"
# 2                                       "Loan Officers"
# 3                            "Accountants and Auditors"
# 4     "Aerospace Engineers"; "Automotive Engineers";...
# ...                                                 ...
# 8780            "Computer Systems Engineers/Architects"
# 8781                                       "Physicists"
# 8782             "Semiconductor Processing Technicians"
# 8783  "Economics Teachers, Postsecondary"; "Politica...
# 8784  "Fundraising Managers"; "Public Relations Mana...
#
# [8785 rows x 2 columns]

# %%
# Merge
software_examples_df = software_examples_df.merge(
    jobs_by_software,
    on='Example',
    how='left'
)

software_examples_df
# Out:
#                                             Example  \
# 0                                     Adobe Acrobat
# 1                                   AdSense Tracker
# 2                                    Atlassian JIRA
# 3                       Blackbaud The Raiser's Edge
# 4     ComputerEase construction accounting software
# ...                                             ...
# 8780                                  AMCS Platform
# 8781                               Dossier software
# 8782                       Mileage logging software
# 8783                             Routeware software
# 8784                                 CompuWeigh GMS
#
#                                     Commodity Title  Commodity Code  \
# 0                      Document management software        43232202
# 1       Data base user interface and query software        43232306
# 2                         Content workflow software        43232201
# 3     Customer relationship management CRM software        43232303
# 4                               Accounting software        43231601
# ...                                             ...             ...
# 8780              Analytical or scientific software        43232605
# 8781    Data base user interface and query software        43232306
# 8782    Data base user interface and query software        43232306
# 8783                          Map creation software        43233506
# 8784    Data base user interface and query software        43232306
#
#       Hot Technology  In Demand  TOTAL_JOBS_PER_SOFTWARE  \
# 0                  1          0                      165
# 1                  0          0                        2
# 2                  1          0                       53
# 3                  0          0                       44
# 4                  0          0                        3
# ...              ...        ...                      ...
# 8780               0          0                        1
# 8781               0          0                        1
# 8782               0          0                        1
# 8783               0          0                        1
# 8784               0          0                        1
#
#       TOTAL_JOBS_PER_SOFTWARE_TYPE  \
# 0                              293
# 1                              632
# 2                               46
# 3                              155
# 4                              178
# ...                            ...
# 8780                           372
# 8781                           632
# 8782                           632
# 8783                            87
# 8784                           632
#
#                                          JOB_TITLE_LIST
# 0     "Accountants and Auditors"; "Administrative La...
# 1              "Chief Executives"; "Marketing Managers"
# 2     "Administrative Services Managers"; "Aerospace...
# 3     "Accountants and Auditors"; "Administrative Se...
# 4     "Bookkeeping, Accounting, and Auditing Clerks"...
# ...                                                 ...
# 8780        "Refuse and Recyclable Material Collectors"
# 8781        "Refuse and Recyclable Material Collectors"
# 8782        "Refuse and Recyclable Material Collectors"
# 8783        "Refuse and Recyclable Material Collectors"
# 8784                "Tank Car, Truck, and Ship Loaders"
#
# [8785 rows x 8 columns]

# %%
software_examples_df.rename(columns={'TOTAL_JOBS_PER_SOFTWARE': 'TOTAL_JOBS_PER_TECH_SKILL'}, inplace=True)
software_examples_df.rename(columns={'TOTAL_JOBS_PER_SOFTWARE_TYPE': 'TOTAL_JOBS_PER_TECH_TYPE'}, inplace=True)
software_examples_df.rename(columns={'Commodity Title': 'Tech Type Title'}, inplace=True)

# Maybe don't change this one? Commodity code is universal. But is it still better to distinguish between tech types and skills?
software_examples_df.rename(columns={'Commodity Code': 'Tech Type Code'}, inplace=True)

software_examples_df.rename(columns={'Example': 'Tech Skill Title'}, inplace=True)

# %%
software_examples_df
# Out:
#                                    Tech Skill Title  \
# 0                                     Adobe Acrobat
# 1                                   AdSense Tracker
# 2                                    Atlassian JIRA
# 3                       Blackbaud The Raiser's Edge
# 4     ComputerEase construction accounting software
# ...                                             ...
# 8780                                  AMCS Platform
# 8781                               Dossier software
# 8782                       Mileage logging software
# 8783                             Routeware software
# 8784                                 CompuWeigh GMS
#
#                                     Tech Type Title  Tech Type Code  \
# 0                      Document management software        43232202
# 1       Data base user interface and query software        43232306
# 2                         Content workflow software        43232201
# 3     Customer relationship management CRM software        43232303
# 4                               Accounting software        43231601
# ...                                             ...             ...
# 8780              Analytical or scientific software        43232605
# 8781    Data base user interface and query software        43232306
# 8782    Data base user interface and query software        43232306
# 8783                          Map creation software        43233506
# 8784    Data base user interface and query software        43232306
#
#       Hot Technology  In Demand  TOTAL_JOBS_PER_TECH_SKILL  \
# 0                  1          0                        165
# 1                  0          0                          2
# 2                  1          0                         53
# 3                  0          0                         44
# 4                  0          0                          3
# ...              ...        ...                        ...
# 8780               0          0                          1
# 8781               0          0                          1
# 8782               0          0                          1
# 8783               0          0                          1
# 8784               0          0                          1
#
#       TOTAL_JOBS_PER_TECH_TYPE  \
# 0                          293
# 1                          632
# 2                           46
# 3                          155
# 4                          178
# ...                        ...
# 8780                       372
# 8781                       632
# 8782                       632
# 8783                        87
# 8784                       632
#
#                                          JOB_TITLE_LIST
# 0     "Accountants and Auditors"; "Administrative La...
# 1              "Chief Executives"; "Marketing Managers"
# 2     "Administrative Services Managers"; "Aerospace...
# 3     "Accountants and Auditors"; "Administrative Se...
# 4     "Bookkeeping, Accounting, and Auditing Clerks"...
# ...                                                 ...
# 8780        "Refuse and Recyclable Material Collectors"
# 8781        "Refuse and Recyclable Material Collectors"
# 8782        "Refuse and Recyclable Material Collectors"
# 8783        "Refuse and Recyclable Material Collectors"
# 8784                "Tank Car, Truck, and Ship Loaders"
#
# [8785 rows x 8 columns]

# %%
software_examples_df.to_csv('transformed data/1-Tech Skills Agg Jobs.csv', index=False)
