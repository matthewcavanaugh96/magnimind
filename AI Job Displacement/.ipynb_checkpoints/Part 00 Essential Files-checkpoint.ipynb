# %%
import pandas as pd

# %% [markdown]
# Essential Files

# %% [raw]
# File Contains
#
# Occupation Data.txt Basic occupation information (title, description, code)
# Task Statements.txt Specific tasks performed in each occupation
# Skills.txt Skills required for each occupation with importance levels
# Abilities.txt Abilities required with importance and level ratings
# Work Activities.txt Generalized work activities with importance/level
# Knowledge.txt Knowledge areas required
# Work Context.txt Environmental and situational context
# Tools and Technology.txt Software, equipment, and tools used

# %% [markdown]
# Other ones that look important:
#
# Interests
#
# Knowledge

# %% [markdown]
# # Occupation Data

# %%
df_occupation_data = pd.read_csv('ONET data/Occupation Data.csv')
df_occupation_data
# Out:
#      O*NET-SOC Code                                              Title  \
# 0        11-1011.00                                   Chief Executives
# 1        11-1011.03                      Chief Sustainability Officers
# 2        11-1021.00                    General and Operations Managers
# 3        11-1031.00                                        Legislators
# 4        11-2011.00                Advertising and Promotions Managers
# ...             ...                                                ...
# 1011     55-3014.00                 Artillery and Missile Crew Members
# 1012     55-3015.00             Command and Control Center Specialists
# 1013     55-3016.00                                           Infantry
# 1014     55-3018.00                                     Special Forces
# 1015     55-3019.00  Military Enlisted Tactical Operations and Air/...
#
#                                             Description
# 0     Determine and formulate policies and provide o...
# ...

# %%
df_occupation_data['Title'].nunique()
# Out:
# 1016

# %% [markdown]
# # Task Statements

# %%
df_task_statements = pd.read_csv('ONET data/Task Statements.csv')
df_task_statements
# Out:
#       O*NET-SOC Code                              Title  Task ID  \
# 0         11-1011.00                   Chief Executives     8823
# 1         11-1011.00                   Chief Executives     8824
# 2         11-1011.00                   Chief Executives     8827
# 3         11-1011.00                   Chief Executives     8826
# 4         11-1011.00                   Chief Executives     8834
# ...              ...                                ...      ...
# 18791     53-7121.00  Tank Car, Truck, and Ship Loaders    12807
# 18792     53-7121.00  Tank Car, Truck, and Ship Loaders    12804
# 18793     53-7121.00  Tank Car, Truck, and Ship Loaders    12803
# 18794     53-7121.00  Tank Car, Truck, and Ship Loaders    12805
# 18795     53-7121.00  Tank Car, Truck, and Ship Loaders    12810
#
#                                                     Task     Task Type  \
# 0      Direct or coordinate an organization's financi...          Core
# ...

# %%
df_task_statements.columns
# Out:
# Index(['O*NET-SOC Code', 'Title', 'Task ID', 'Task', 'Task Type',
#        'Incumbents Responding', 'Date', 'Domain Source'],
#       dtype='object')

# %%
df_task_statements['Title'].nunique()
# Out:
# 923

# %%
df_task_statements['Task'].nunique()
# Out:
# 17537

# %%
df_task_statements['Task ID'].nunique()
# Out:
# 18796

# %% [markdown]
# # Skills

# %%
df_skills = pd.read_csv('ONET data/Skills.csv')
df_skills
# Out:
#       O*NET-SOC Code                              Title Element ID  \
# 0         11-1011.00                   Chief Executives    2.A.1.a
# 1         11-1011.00                   Chief Executives    2.A.1.a
# 2         11-1011.00                   Chief Executives    2.A.1.b
# 3         11-1011.00                   Chief Executives    2.A.1.b
# 4         11-1011.00                   Chief Executives    2.A.1.c
# ...              ...                                ...        ...
# 62575     53-7121.00  Tank Car, Truck, and Ship Loaders    2.B.5.b
# 62576     53-7121.00  Tank Car, Truck, and Ship Loaders    2.B.5.c
# 62577     53-7121.00  Tank Car, Truck, and Ship Loaders    2.B.5.c
# 62578     53-7121.00  Tank Car, Truck, and Ship Loaders    2.B.5.d
# 62579     53-7121.00  Tank Car, Truck, and Ship Loaders    2.B.5.d
#
#                             Element Name Scale ID  Scale Name  Data Value  N  \
# 0                  Reading Comprehension       IM  Importance        4.12  8
# ...

# %% [markdown]
# # Abilities

# %%
df_abilities = pd.read_csv('ONET data/Abilities.csv')
df_abilities
# Out:
#       O*NET-SOC Code                              Title Element ID  \
# 0         11-1011.00                   Chief Executives  1.A.1.a.1
# 1         11-1011.00                   Chief Executives  1.A.1.a.1
# 2         11-1011.00                   Chief Executives  1.A.1.a.2
# 3         11-1011.00                   Chief Executives  1.A.1.a.2
# 4         11-1011.00                   Chief Executives  1.A.1.a.3
# ...              ...                                ...        ...
# 92971     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.3
# 92972     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.4
# 92973     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.4
# 92974     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.5
# 92975     53-7121.00  Tank Car, Truck, and Ship Loaders  1.A.4.b.5
#
#                 Element Name Scale ID  Scale Name  Data Value  N  \
# 0         Oral Comprehension       IM  Importance        4.62  8
# ...

# %% [markdown]
# # Work Activities

# %%
df_work_activities = pd.read_csv('ONET data/Work Activities.csv')
df_work_activities
# Out:
#       O*NET-SOC Code                              Title Element ID  \
# 0         11-1011.00                   Chief Executives  4.A.1.a.1
# 1         11-1011.00                   Chief Executives  4.A.1.a.1
# 2         11-1011.00                   Chief Executives  4.A.1.a.2
# 3         11-1011.00                   Chief Executives  4.A.1.a.2
# 4         11-1011.00                   Chief Executives  4.A.1.b.1
# ...              ...                                ...        ...
# 73303     53-7121.00  Tank Car, Truck, and Ship Loaders  4.A.4.c.1
# 73304     53-7121.00  Tank Car, Truck, and Ship Loaders  4.A.4.c.2
# 73305     53-7121.00  Tank Car, Truck, and Ship Loaders  4.A.4.c.2
# 73306     53-7121.00  Tank Car, Truck, and Ship Loaders  4.A.4.c.3
# 73307     53-7121.00  Tank Car, Truck, and Ship Loaders  4.A.4.c.3
#
#                                            Element Name Scale ID  Scale Name  \
# 0                                   Getting Information       IM  Importance
# ...

# %% [markdown]
# # Knowledge

# %%
df_knowledge = pd.read_csv('ONET data/Knowledge.csv')
df_knowledge
# Out:
#       O*NET-SOC Code                              Title Element ID  \
# 0         11-1011.00                   Chief Executives    2.C.1.a
# 1         11-1011.00                   Chief Executives    2.C.1.a
# 2         11-1011.00                   Chief Executives    2.C.1.b
# 3         11-1011.00                   Chief Executives    2.C.1.b
# 4         11-1011.00                   Chief Executives    2.C.1.c
# ...              ...                                ...        ...
# 58999     53-7121.00  Tank Car, Truck, and Ship Loaders    2.C.9.a
# 59000     53-7121.00  Tank Car, Truck, and Ship Loaders    2.C.9.b
# 59001     53-7121.00  Tank Car, Truck, and Ship Loaders    2.C.9.b
# 59002     53-7121.00  Tank Car, Truck, and Ship Loaders     2.C.10
# 59003     53-7121.00  Tank Car, Truck, and Ship Loaders     2.C.10
#
#                         Element Name Scale ID  Scale Name  Data Value     N  \
# 0      Administration and Management       IM  Importance        4.78  28.0
# ...

# %% [markdown]
# # Work Context

# %%
df_work_context = pd.read_csv('ONET data/Work Context.csv')
df_work_context
# Out:
#        O*NET-SOC Code                              Title   Element ID  \
# 0          11-1011.00                   Chief Executives  4.C.1.a.2.c
# 1          11-1011.00                   Chief Executives  4.C.1.a.2.c
# 2          11-1011.00                   Chief Executives  4.C.1.a.2.c
# 3          11-1011.00                   Chief Executives  4.C.1.a.2.c
# 4          11-1011.00                   Chief Executives  4.C.1.a.2.c
# ...               ...                                ...          ...
# 297671     53-7121.00  Tank Car, Truck, and Ship Loaders    4.C.3.d.4
# 297672     53-7121.00  Tank Car, Truck, and Ship Loaders    4.C.3.d.8
# 297673     53-7121.00  Tank Car, Truck, and Ship Loaders    4.C.3.d.8
# 297674     53-7121.00  Tank Car, Truck, and Ship Loaders    4.C.3.d.8
# 297675     53-7121.00  Tank Car, Truck, and Ship Loaders    4.C.3.d.8
#
#                          Element Name Scale ID                Scale Name  \
# ...

# %% [markdown]
# # Tools

# %%
df_tools_used = pd.read_csv('ONET data/Tools Used.csv')
df_tools_used
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 41657     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41658     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41659     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41660     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41661     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                Example  Commodity Code  \
# 0                   10-key calculators        44101809
# 1                    Desktop computers        43211507
# 2                     Laptop computers        43211503
# 3                   Personal computers        43211508
# ...

# %% [markdown]
# # Technology

# %%
df_technology_skills = pd.read_csv('ONET data/Technology Skills.csv')
df_technology_skills
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 32768     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32769     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32770     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32771     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32772     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                              Example  Commodity Code  \
# 0                                      Adobe Acrobat        43232202
# 1                                    AdSense Tracker        43232306
# 2                                     Atlassian JIRA        43232201
# ...

# %%
df_technology_skills['O*NET-SOC Code'].nunique()
# Out:
# 923

# %%
df_technology_skills['Title'].nunique()
# Out:
# 923

# %%
df_technology_skills['Example'].nunique()
# Out:
# 8785

# %%
df_technology_skills['Commodity Code'].nunique()
# Out:
# 137

# %%
df_technology_skills['Commodity Title'].nunique()
# Out:
# 137

# %% [markdown]
# # Everything below has been moved to other notebook.

# %%
total_skills_by_title = (
    df_technology_skills
    .groupby(['O*NET-SOC Code', 'Title'])['Example']
    .nunique()
    .reset_index(name='TOTAL_EXAMPLES')
    .sort_values('TOTAL_EXAMPLES', ascending=False)
)

total_skills_by_title
# Out:
#     O*NET-SOC Code                                              Title  \
# 117     15-1252.00                                Software Developers
# 118     15-1253.00    Software Quality Assurance Analysts and Testers
# 130     15-1299.09            Information Technology Project Managers
# 113     15-1243.00                                Database Architects
# 104     15-1211.00                          Computer Systems Analysts
# ..             ...                                                ...
# 527     35-9021.00                                        Dishwashers
# 910     53-7041.00                          Hoist and Winch Operators
# 893     53-4041.00                     Subway and Streetcar Operators
# 783     51-4023.00  Rolling Machine Setters, Operators, and Tender...
# 780     51-3093.00         Food Cooking Machine Operators and Tenders
#
#      TOTAL_EXAMPLES
# 117             429
# 118             428
# 130             334
# 113             324
# ...

# %%
total_commods_by_title = (
    df_technology_skills
    .groupby(['O*NET-SOC Code', 'Title'])['Commodity Code']
    .nunique()
    .reset_index(name='TOTAL_COMMODITIES')
    .sort_values('TOTAL_COMMODITIES', ascending=False)
)

total_commods_by_title
# Out:
#     O*NET-SOC Code                                            Title  \
# 109     15-1232.00                Computer User Support Specialists
# 129     15-1299.08            Computer Systems Engineers/Architects
# 118     15-1253.00  Software Quality Assurance Analysts and Testers
# 104     15-1211.00                        Computer Systems Analysts
# 115     15-1244.00      Network and Computer Systems Administrators
# ..             ...                                              ...
# 893     53-4041.00                   Subway and Streetcar Operators
# 910     53-7041.00                        Hoist and Winch Operators
# 413     29-1214.00                    Emergency Medicine Physicians
# 752     49-9063.00          Musical Instrument Repairers and Tuners
# 780     51-3093.00       Food Cooking Machine Operators and Tenders
#
#      TOTAL_COMMODITIES
# 109                 75
# 129                 69
# 118                 68
# 104                 68
# 115                 68
# ...

# %%
soc_commodity_breakdown = (
    df_technology_skills
    .groupby([
        'O*NET-SOC Code', 'Title'
    ])
    .agg(
        num_examples=('Example', 'nunique'),
        example_list=('Example',
                      lambda x: '; '.join(
                          f'"{e}"' for e in sorted(x.unique())
                      ))
    )
    .reset_index()
)

soc_commodity_breakdown
# Out:
#     O*NET-SOC Code                                             Title  \
# 0       11-1011.00                                  Chief Executives
# 1       11-1011.03                     Chief Sustainability Officers
# 2       11-1021.00                   General and Operations Managers
# 3       11-1031.00                                       Legislators
# 4       11-2011.00               Advertising and Promotions Managers
# ..             ...                                               ...
# 918     53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 919     53-7072.00           Pump Operators, Except Wellhead Pumpers
# 920     53-7073.00                                  Wellhead Pumpers
# 921     53-7081.00         Refuse and Recyclable Material Collectors
# 922     53-7121.00                 Tank Car, Truck, and Ship Loaders
#
#      num_examples                                       example_list
# 0              49  "AdSense Tracker"; "Adobe Acrobat"; "Atlassian...
# ...

# %% [markdown]
# # Next, I should look at how many JOB TITLES each EXAMPLE is associated with. Then, each job can be assigned a score for the uniqueness of the skills required.

# %% [markdown]
# # Everything below here is old.

# %%
grouped_by_code_and_commod = (
    df_technology_skills
    .groupby(['Commodity Code', 'O*NET-SOC Code', 'Title'])['Example']
    .nunique()
    .reset_index(name='num_examples')
    .sort_values('num_examples', ascending=False)
)

grouped_by_code_and_commod
# Out:
#        Commodity Code O*NET-SOC Code  \
# 9475         43232605     19-2043.00
# 9474         43232605     19-2042.00
# 2332         43231604     13-2051.00
# 9965         43232610     29-1222.00
# 2335         43231604     13-2054.00
# ...               ...            ...
# 4994         43232110     17-2011.00
# 4995         43232110     17-2021.00
# 4996         43232110     17-2031.00
# 4999         43232110     17-2051.01
# 12907        43233701     43-6014.00
#
#                                                    Title  num_examples
# 9475                                        Hydrologists            92
# 9474   Geoscientists, Except Hydrologists and Geograp...            84
# 2332                   Financial and Investment Analysts            81
# 9965                            Physicians, Pathologists            81
# 2335                          Financial Risk Specialists            77
# ...                                                  ...           ...
# ...

# %%
soc_commodity_breakdown = (
    df_technology_skills
    .groupby([
        'O*NET-SOC Code',
        'Title',
        'Commodity Code',
        'Commodity Title'
    ])
    .agg(
        num_examples=('Example', 'nunique'),
        example_list=('Example',
                      lambda x: '; '.join(
                          f'"{e}"' for e in sorted(x.unique())
                      ))
    )
    .reset_index()
)

# %%
soc_commodity_breakdown
# Out:
#       O*NET-SOC Code                              Title  Commodity Code  \
# 0         11-1011.00                   Chief Executives        43231505
# 1         11-1011.00                   Chief Executives        43231507
# 2         11-1011.00                   Chief Executives        43231513
# 3         11-1011.00                   Chief Executives        43231601
# 4         11-1011.00                   Chief Executives        43231602
# ...              ...                                ...             ...
# 12903     53-7121.00  Tank Car, Truck, and Ship Loaders        43231513
# 12904     53-7121.00  Tank Car, Truck, and Ship Loaders        43231602
# 12905     53-7121.00  Tank Car, Truck, and Ship Loaders        43232110
# 12906     53-7121.00  Tank Car, Truck, and Ship Loaders        43232306
# 12907     53-7121.00  Tank Car, Truck, and Ship Loaders        43233004
#
#                                    Commodity Title  num_examples  \
# ...

# %%
soc_commodity_breakdown['num_examples'].value_counts()
# Out:
# num_examples
# 1     7816
# 2     2307
# 3      912
# 4      486
# 5      349
#       ...
# 39       1
# 54       1
# 57       1
# 68       1
# 62       1
# Name: count, Length: 65, dtype: int64

# %%
soc_commodity_breakdown.nlargest(10, 'num_examples')
# Out:
#      O*NET-SOC Code                                              Title  \
# 5212     19-2043.00                                       Hydrologists
# 5195     19-2042.00  Geoscientists, Except Hydrologists and Geograp...
# 2044     13-2051.00                  Financial and Investment Analysts
# 8006     29-1222.00                           Physicians, Pathologists
# 2103     13-2054.00                         Financial Risk Specialists
# 7366     27-2041.00                      Music Directors and Composers
# 7083     27-1014.00              Special Effects Artists and Animators
# 1469     13-1071.00                        Human Resources Specialists
# 3465     15-1299.09            Information Technology Project Managers
# 2953     15-1252.00                                Software Developers
#
#       Commodity Code                     Commodity Title  num_examples  \
# 5212        43232605   Analytical or scientific software            92
# ...

# %%
soc_commodity_breakdown.nsmallest(10, 'num_examples')
# Out:
#    O*NET-SOC Code             Title  Commodity Code  \
# 2      11-1011.00  Chief Executives        43231513
# 5      11-1011.00  Chief Executives        43231604
# 8      11-1011.00  Chief Executives        43232104
# 10     11-1011.00  Chief Executives        43232110
# 11     11-1011.00  Chief Executives        43232112
# 12     11-1011.00  Chief Executives        43232201
# 15     11-1011.00  Chief Executives        43232304
# 16     11-1011.00  Chief Executives        43232305
# 18     11-1011.00  Chief Executives        43232403
# 19     11-1011.00  Chief Executives        43232408
#
#                                 Commodity Title  num_examples  \
# 2                         Office suite software             1
# 5                   Financial analysis software             1
# 8                      Word processing software             1
# 10                         Spreadsheet software             1
# 11                  Desktop publishing software             1
# ...

# %%
commod_types_by_job = (
    soc_commodity_breakdown
        .groupby("Title")["Commodity Title"]
        .nunique()
        .reset_index(name="Number of Commodity Types per Job Title")
)

commod_types_by_job
# Out:
#                                                  Title  \
# 0                             Accountants and Auditors
# 1                                               Actors
# 2                                            Actuaries
# 3                                       Acupuncturists
# 4                                    Acute Care Nurses
# ..                                                 ...
# 918                   Wind Turbine Service Technicians
# 919  Woodworking Machine Setters, Operators, and Te...
# 920                        Word Processors and Typists
# 921                                Writers and Authors
# 922                 Zoologists and Wildlife Biologists
#
#      Number of Commodity Types per Job Title
# 0                                         37
# 1                                         12
# 2                                         15
# 3                                          6
# 4                                          9
# ...
