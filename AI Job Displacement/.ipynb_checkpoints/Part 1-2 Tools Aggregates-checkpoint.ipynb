# %%
import pandas as pd

df_occupation_data = pd.read_csv('ONET data/Occupation Data.csv')
df_task_statements = pd.read_csv('ONET data/Task Statements.csv')
df_skills = pd.read_csv('ONET data/Skills.csv')
df_abilities = pd.read_csv('ONET data/Abilities.csv')
df_work_activities = pd.read_csv('ONET data/Work Activities.csv')
df_knowledge = pd.read_csv('ONET data/Knowledge.csv')
df_work_context = pd.read_csv('ONET data/Work Context.csv')
df_tools_used = pd.read_csv('ONET data/Tools Used.csv')
df_technology_skills = pd.read_csv('ONET data/Technology Skills.csv')

dfs = {
    "occupation_data": df_occupation_data,
    "task_statements": df_task_statements,
    "skills": df_skills,
    "abilities": df_abilities,
    "work_activities": df_work_activities,
    "knowledge": df_knowledge,
    "work_context": df_work_context,
    "tools_used": df_tools_used,
    "technology_skills": df_technology_skills
}

# %% [markdown]
# # Tools Aggregates

# %%
df_tools_used
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 41657     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41658     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41659     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41660     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41661     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                Example  Commodity Code  \
# 0                   10-key calculators        44101809
# 1                    Desktop computers        43211507
# 2                     Laptop computers        43211503
# 3                   Personal computers        43211508
# 4      Personal digital assistants PDA        43211504
# ...                                ...             ...
# 41657                    Stock pickers        24101605
# 41658                 Tablet computers        43211509
# 41659         Walk behind pallet jacks        24101505
# 41660              Warehouse forklifts        24101603
# 41661        Wheeled front end loaders        22101501
#
#                                     Commodity Title
# 0                                Desktop calculator
# 1                                  Desktop computer
# 2                                 Notebook computer
# 3                                 Personal computer
# 4      Personal digital assistant PDAs or organizer
# ...                                             ...
# 41657                             Loading equipment
# 41658                               Tablet computer
# 41659                                 Pallet trucks
# 41660                                     Forklifts
# 41661                             Front end loaders
#
# [41662 rows x 5 columns]

# %%
df_tools_used['Commodity Code'].nunique()
# Out:
# 4127

# %%
df_tools_used['Commodity Title'].nunique()
# Out:
# 4126

# %%
df_tools_used.columns
# Out:
# Index(['O*NET-SOC Code', 'Title', 'Example', 'Commodity Code',
#        'Commodity Title'],
#       dtype='object')

# %%
code_title_counts = (
    df_tools_used
    .groupby('Commodity Code')['Commodity Title']
    .nunique()
    .reset_index(name='num_unique_titles')
)

code_title_counts['num_unique_titles'].value_counts()
# Out:
# num_unique_titles
# 1    4127
# Name: count, dtype: int64

# %%
title_code_counts = (
    df_tools_used
    .groupby('Commodity Title')['Commodity Code']
    .nunique()
    .reset_index(name='num_unique_codes')
)

#title_code_counts.sort_values('num_unique_codes', ascending=False).head()
title_code_counts[title_code_counts['num_unique_codes'] > 1]
# Out:
#                     Commodity Title  num_unique_codes
# 1471  Freeze dryers or lyophilizers                 2

# %%
df_tools_used[df_tools_used['Commodity Title'] == 'Freeze dryers or lyophilizers']
# Out:
#      O*NET-SOC Code                                              Title  \
# 2019     17-2031.00              Bioengineers and Biomedical Engineers
# 2166     17-2041.00                                 Chemical Engineers
# 2414     17-2081.00                            Environmental Engineers
# 3998     17-3025.00  Environmental Engineering Technologists and Te...
# 4838     19-1011.00                                  Animal Scientists
# 4930     19-1012.00                  Food Scientists and Technologists
# 5122     19-1021.00                      Biochemists and Biophysicists
# 5126     19-1021.00                      Biochemists and Biophysicists
# 5234     19-1021.00                      Biochemists and Biophysicists
# 5295     19-1022.00                                    Microbiologists
# 5595     19-1029.04                                         Biologists
# 6139     19-2031.00                                           Chemists
# 6176     19-2031.00                                           Chemists
# 6326     19-2032.00                               Materials Scientists
# 7012     19-3091.00                  Anthropologists and Archeologists
# 7515     19-4031.00                               Chemical Technicians
#
#                             Example  Commodity Code  \
# 2019                  Freeze dryers        41104701
# 2166                   Lyophilizers        23151807
# 2414                  Freeze dryers        41104701
# 3998                  Freeze dryers        41104701
# 4838                  Freeze dryers        41104701
# 4930        Freeze drying equipment        41104701
# 5122         Flexi-dry lyophilizers        41104701
# 5126                  Freeze dryers        41104701
# 5234                Vacuum freezers        41104701
# 5295                  Freeze dryers        41104701
# 5595          Benchtop lyophilizers        23151807
# 6139          Benchtop lyophilizers        23151807
# 6176                  Freeze dryers        41104701
# 6326                  Freeze dryers        41104701
# 7012  Vacuum freeze-drying chambers        41104701
# 7515                   Lyophilizers        23151807
#
#                     Commodity Title
# 2019  Freeze dryers or lyophilizers
# 2166  Freeze dryers or lyophilizers
# 2414  Freeze dryers or lyophilizers
# 3998  Freeze dryers or lyophilizers
# 4838  Freeze dryers or lyophilizers
# 4930  Freeze dryers or lyophilizers
# 5122  Freeze dryers or lyophilizers
# 5126  Freeze dryers or lyophilizers
# 5234  Freeze dryers or lyophilizers
# 5295  Freeze dryers or lyophilizers
# 5595  Freeze dryers or lyophilizers
# 6139  Freeze dryers or lyophilizers
# 6176  Freeze dryers or lyophilizers
# 6326  Freeze dryers or lyophilizers
# 7012  Freeze dryers or lyophilizers
# 7515  Freeze dryers or lyophilizers

# %%
df_tools_used[df_tools_used['Commodity Code'] == 23151807]
# Out:
#      O*NET-SOC Code                 Title                Example  \
# 2166     17-2041.00    Chemical Engineers           Lyophilizers
# 5595     19-1029.04            Biologists  Benchtop lyophilizers
# 6139     19-2031.00              Chemists  Benchtop lyophilizers
# 7515     19-4031.00  Chemical Technicians           Lyophilizers
#
#       Commodity Code                Commodity Title
# 2166        23151807  Freeze dryers or lyophilizers
# 5595        23151807  Freeze dryers or lyophilizers
# 6139        23151807  Freeze dryers or lyophilizers
# 7515        23151807  Freeze dryers or lyophilizers

# %%
df_tools_used['Commodity Code'] = df_tools_used['Commodity Code'].replace(23151807, 41104701)

# %%
df_tools_used[df_tools_used['Commodity Title'] == 'Freeze dryers or lyophilizers']
# Out:
#      O*NET-SOC Code                                              Title  \
# 2019     17-2031.00              Bioengineers and Biomedical Engineers
# 2166     17-2041.00                                 Chemical Engineers
# 2414     17-2081.00                            Environmental Engineers
# 3998     17-3025.00  Environmental Engineering Technologists and Te...
# 4838     19-1011.00                                  Animal Scientists
# 4930     19-1012.00                  Food Scientists and Technologists
# 5122     19-1021.00                      Biochemists and Biophysicists
# 5126     19-1021.00                      Biochemists and Biophysicists
# 5234     19-1021.00                      Biochemists and Biophysicists
# 5295     19-1022.00                                    Microbiologists
# 5595     19-1029.04                                         Biologists
# 6139     19-2031.00                                           Chemists
# 6176     19-2031.00                                           Chemists
# 6326     19-2032.00                               Materials Scientists
# 7012     19-3091.00                  Anthropologists and Archeologists
# 7515     19-4031.00                               Chemical Technicians
#
#                             Example  Commodity Code  \
# 2019                  Freeze dryers        41104701
# 2166                   Lyophilizers        41104701
# 2414                  Freeze dryers        41104701
# 3998                  Freeze dryers        41104701
# 4838                  Freeze dryers        41104701
# 4930        Freeze drying equipment        41104701
# 5122         Flexi-dry lyophilizers        41104701
# 5126                  Freeze dryers        41104701
# 5234                Vacuum freezers        41104701
# 5295                  Freeze dryers        41104701
# 5595          Benchtop lyophilizers        41104701
# 6139          Benchtop lyophilizers        41104701
# 6176                  Freeze dryers        41104701
# 6326                  Freeze dryers        41104701
# 7012  Vacuum freeze-drying chambers        41104701
# 7515                   Lyophilizers        41104701
#
#                     Commodity Title
# 2019  Freeze dryers or lyophilizers
# 2166  Freeze dryers or lyophilizers
# 2414  Freeze dryers or lyophilizers
# 3998  Freeze dryers or lyophilizers
# 4838  Freeze dryers or lyophilizers
# 4930  Freeze dryers or lyophilizers
# 5122  Freeze dryers or lyophilizers
# 5126  Freeze dryers or lyophilizers
# 5234  Freeze dryers or lyophilizers
# 5295  Freeze dryers or lyophilizers
# 5595  Freeze dryers or lyophilizers
# 6139  Freeze dryers or lyophilizers
# 6176  Freeze dryers or lyophilizers
# 6326  Freeze dryers or lyophilizers
# 7012  Freeze dryers or lyophilizers
# 7515  Freeze dryers or lyophilizers

# %%
title_code_counts = (
    df_tools_used
    .groupby('Commodity Title')['Commodity Code']
    .nunique()
    .reset_index(name='num_unique_codes')
)

#title_code_counts.sort_values('num_unique_codes', ascending=False).head()
title_code_counts[title_code_counts['num_unique_codes'] > 1]
# Out:
# Empty DataFrame
# Columns: [Commodity Title, num_unique_codes]
# Index: []

# %% [markdown]
# # Mismatch Fixed. Now we can move on to...
#
# # Aggregates

# %%
# Reset DF definition
df_tools_used = pd.read_csv('ONET data/Tools Used.csv')
df_tools_used['Commodity Code'] = df_tools_used['Commodity Code'].replace(23151807, 41104701)

# %%
df_tools_used
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 41657     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41658     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41659     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41660     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41661     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                Example  Commodity Code  \
# 0                   10-key calculators        44101809
# 1                    Desktop computers        43211507
# 2                     Laptop computers        43211503
# 3                   Personal computers        43211508
# 4      Personal digital assistants PDA        43211504
# ...                                ...             ...
# 41657                    Stock pickers        24101605
# 41658                 Tablet computers        43211509
# 41659         Walk behind pallet jacks        24101505
# 41660              Warehouse forklifts        24101603
# 41661        Wheeled front end loaders        22101501
#
#                                     Commodity Title
# 0                                Desktop calculator
# 1                                  Desktop computer
# 2                                 Notebook computer
# 3                                 Personal computer
# 4      Personal digital assistant PDAs or organizer
# ...                                             ...
# 41657                             Loading equipment
# 41658                               Tablet computer
# 41659                                 Pallet trucks
# 41660                                     Forklifts
# 41661                             Front end loaders
#
# [41662 rows x 5 columns]

# %%
# Find count of unique tools by title
total_tools_by_title = (
    df_tools_used
    .groupby(['O*NET-SOC Code', 'Title'])['Example']
    .nunique()
    .reset_index(name='TOTAL_TOOLS_BY_JOB')
    .sort_values('TOTAL_TOOLS_BY_JOB', ascending=False)
)

# Find count of unique tools by title
total_tool_types_by_title = (
    df_tools_used
    .groupby(['O*NET-SOC Code', 'Commodity Title'])['Example']
    .nunique()
    .reset_index(name='TOTAL_TOOL_TYPES_BY_JOB')
    .sort_values('TOTAL_TOOL_TYPES_BY_JOB', ascending=False)
)

# Create column list of all tools by title
tools_by_title = (
    df_tools_used
    .groupby('Title')['Example']
    .apply(lambda x: '; '.join(
        f'"{e}"' for e in sorted(x.unique())
    ))
    .reset_index(name='TOOLS_LIST')
)

# Create column list of all tools by title
tools_by_title = (
    df_tools_used
    .groupby('Title')['Example']
    .apply(lambda x: '; '.join(
        f'"{e}"' for e in sorted(x.unique())
    ))
    .reset_index(name='TOOLS_LIST')
)

# %%
# Merge
titles_tools_and_types = df_tools_used.merge(
    total_tools_by_title,
    on=['Title', 'O*NET-SOC Code'],
    how='left'
)

# Merge
titles_tools_and_types = titles_tools_and_types.merge(
    total_tool_types_by_title,
    on=['Commodity Title', 'O*NET-SOC Code'],
    how='left'
)

# Merge
titles_tools_and_types = titles_tools_and_types.merge(
    tools_by_title,
    on=['Title'],
    how='left'
)

# Merge
titles_tools_and_types = titles_tools_and_types.merge(
    tool_types_by_title,
    on=['Title'],
    how='left'
)

# %%
titles_tools_and_types
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 41657     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41658     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41659     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41660     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41661     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                Example  Commodity Code  \
# 0                   10-key calculators        44101809
# 1                    Desktop computers        43211507
# 2                     Laptop computers        43211503
# 3                   Personal computers        43211508
# 4      Personal digital assistants PDA        43211504
# ...                                ...             ...
# 41657                    Stock pickers        24101605
# 41658                 Tablet computers        43211509
# 41659         Walk behind pallet jacks        24101505
# 41660              Warehouse forklifts        24101603
# 41661        Wheeled front end loaders        22101501
#
#                                     Commodity Title  TOTAL_TOOLS_BY_JOB  \
# 0                                Desktop calculator                   7
# 1                                  Desktop computer                   7
# 2                                 Notebook computer                   7
# 3                                 Personal computer                   7
# 4      Personal digital assistant PDAs or organizer                   7
# ...                                             ...                 ...
# 41657                             Loading equipment                  17
# 41658                               Tablet computer                  17
# 41659                                 Pallet trucks                  17
# 41660                                     Forklifts                  17
# 41661                             Front end loaders                  17
#
#        TOTAL_TOOL_TYPES_BY_JOB  \
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
# ...                        ...
# 41657                        2
# 41658                        1
# 41659                        2
# 41660                        1
# 41661                        1
#
#                                               TOOLS_LIST  \
# 0      "10-key calculators"; "Desktop computers"; "La...
# 1      "10-key calculators"; "Desktop computers"; "La...
# 2      "10-key calculators"; "Desktop computers"; "La...
# 3      "10-key calculators"; "Desktop computers"; "La...
# 4      "10-key calculators"; "Desktop computers"; "La...
# ...                                                  ...
# 41657  "Computer laser printers"; "Conveyor belt syst...
# 41658  "Computer laser printers"; "Conveyor belt syst...
# 41659  "Computer laser printers"; "Conveyor belt syst...
# 41660  "Computer laser printers"; "Conveyor belt syst...
# 41661  "Computer laser printers"; "Conveyor belt syst...
#
#                                           TOOL_TYPE_LIST
# 0      "Desktop calculator"; "Desktop computer"; "Hig...
# 1      "Desktop calculator"; "Desktop computer"; "Hig...
# 2      "Desktop calculator"; "Desktop computer"; "Hig...
# 3      "Desktop calculator"; "Desktop computer"; "Hig...
# 4      "Desktop calculator"; "Desktop computer"; "Hig...
# ...                                                  ...
# 41657  "Belt conveyors"; "Floor or platform scales"; ...
# 41658  "Belt conveyors"; "Floor or platform scales"; ...
# 41659  "Belt conveyors"; "Floor or platform scales"; ...
# 41660  "Belt conveyors"; "Floor or platform scales"; ...
# 41661  "Belt conveyors"; "Floor or platform scales"; ...
#
# [41662 rows x 9 columns]

# %%
titles_tools_and_types.rename(columns={'Title': 'Job Title'}, inplace=True)
titles_tools_and_types.rename(columns={'Example': 'Tool Name'}, inplace=True)
titles_tools_and_types.rename(columns={'Commodity Code': 'Tool Type Code'}, inplace=True)
titles_tools_and_types.rename(columns={'Commodity Title': 'Tool Type Title'}, inplace=True)

# %%
titles_tools_and_types
# Out:
#       O*NET-SOC Code                          Job Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 41657     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41658     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41659     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41660     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41661     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                              Tool Name  Tool Type Code  \
# 0                   10-key calculators        44101809
# 1                    Desktop computers        43211507
# 2                     Laptop computers        43211503
# 3                   Personal computers        43211508
# 4      Personal digital assistants PDA        43211504
# ...                                ...             ...
# 41657                    Stock pickers        24101605
# 41658                 Tablet computers        43211509
# 41659         Walk behind pallet jacks        24101505
# 41660              Warehouse forklifts        24101603
# 41661        Wheeled front end loaders        22101501
#
#                                     Tool Type Title  TOTAL_TOOLS_BY_JOB  \
# 0                                Desktop calculator                   7
# 1                                  Desktop computer                   7
# 2                                 Notebook computer                   7
# 3                                 Personal computer                   7
# 4      Personal digital assistant PDAs or organizer                   7
# ...                                             ...                 ...
# 41657                             Loading equipment                  17
# 41658                               Tablet computer                  17
# 41659                                 Pallet trucks                  17
# 41660                                     Forklifts                  17
# 41661                             Front end loaders                  17
#
#        TOTAL_TOOL_TYPES_BY_JOB  \
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
# ...                        ...
# 41657                        2
# 41658                        1
# 41659                        2
# 41660                        1
# 41661                        1
#
#                                               TOOLS_LIST  \
# 0      "10-key calculators"; "Desktop computers"; "La...
# 1      "10-key calculators"; "Desktop computers"; "La...
# 2      "10-key calculators"; "Desktop computers"; "La...
# 3      "10-key calculators"; "Desktop computers"; "La...
# 4      "10-key calculators"; "Desktop computers"; "La...
# ...                                                  ...
# 41657  "Computer laser printers"; "Conveyor belt syst...
# 41658  "Computer laser printers"; "Conveyor belt syst...
# 41659  "Computer laser printers"; "Conveyor belt syst...
# 41660  "Computer laser printers"; "Conveyor belt syst...
# 41661  "Computer laser printers"; "Conveyor belt syst...
#
#                                           TOOL_TYPE_LIST
# 0      "Desktop calculator"; "Desktop computer"; "Hig...
# 1      "Desktop calculator"; "Desktop computer"; "Hig...
# 2      "Desktop calculator"; "Desktop computer"; "Hig...
# 3      "Desktop calculator"; "Desktop computer"; "Hig...
# 4      "Desktop calculator"; "Desktop computer"; "Hig...
# ...                                                  ...
# 41657  "Belt conveyors"; "Floor or platform scales"; ...
# 41658  "Belt conveyors"; "Floor or platform scales"; ...
# 41659  "Belt conveyors"; "Floor or platform scales"; ...
# 41660  "Belt conveyors"; "Floor or platform scales"; ...
# 41661  "Belt conveyors"; "Floor or platform scales"; ...
#
# [41662 rows x 9 columns]

# %%
titles_tools_and_types.to_csv('transformed data/2-Jobs Agg Tools.csv', index=False)

# %% [markdown]
# # Next - Need to aggregate Tools by Jobs - The reverse of what was done above
