# %%
import pandas as pd

# %%
models_df = pd.read_csv('transformed data/3-Model Scores and Consensus.csv')
models_df
# Out:
#     O*NET-SOC Code                                             Title  \
# 0       11-1011.00                                  Chief Executives
# 1       11-1011.03                     Chief Sustainability Officers
# 2       11-1021.00                   General and Operations Managers
# 3       11-2011.00               Advertising and Promotions Managers
# 4       11-2021.00                                Marketing Managers
# ..             ...                                               ...
# 889     53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 890     53-7072.00           Pump Operators, Except Wellhead Pumpers
# 891     53-7073.00                                  Wellhead Pumpers
# 892     53-7081.00         Refuse and Recyclable Material Collectors
# 893     53-7121.00                 Tank Car, Truck, and Ship Loaders
#
#      GPT_V1_doubleweighed  Claude_V1_doubleweighed  Gemini_V1_doubleweighed  \
# ...

# %%
models_df.columns
# Out:
# Index(['O*NET-SOC Code', 'Title', 'GPT_V1_doubleweighed',
#        'Claude_V1_doubleweighed', 'Gemini_V1_doubleweighed',
#        'Multi Model Consensus', 'Consensus Rank', 'Displacement Risk Category',
#        'Displacement Risk Category v2', 'Model Disagreement', 'Description',
#        'aliases', 'ChatGPT blind score', 'Consensus change vs blind score'],
#       dtype='object')
